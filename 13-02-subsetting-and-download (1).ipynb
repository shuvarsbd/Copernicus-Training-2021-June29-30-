# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)

# %% [markdown]
# # COPERNICUS MARINE IN SITU AMERICA TRAINING (2/5)
#
# <div style="text-align: right"><i> 13-03-Part-two-out-of-five </i></div>

# %% [markdown]
# # SUBSETTING & DOWNLOAD

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction">1. Introduction</a></span></li>
#         <li>
#             <span><a href="#2.-Setup" data-toc-modified-id="2.-Setup">2. Setup</a></span>
#             <ul>
#                 <li><span><a href="#2.1.-Python-packages" data-toc-modified-id="2.1.-Python-packages">2.1. Python packages</a></span></li>
#                 <li><span><a href="#2.2.-Copernicus-Database" data-toc-modified-id="2.2.-Copernicus-Database">2.2. Copernicus database</a></span></li>
#                 <li><span><a href="#2.3.-Search-constrains" data-toc-modified-id="2.3-Search-constrains">2.3. Search constrains</a></span></li>
#             </ul>
#         </li>
#         <li><span><a href="#3.-Getting-started" data-toc-modified-id="3.-Getting-started">3. Getting started</a></span></li>
#         <li><span><a href="#4.-Operations" data-toc-modified-id="4.-Operations">4. Operations</a></span>
#         <ul>
#             <li>
#             <span><a href="#4.1.-Subsetting" data-toc-modified-id="4.1.-Subsetting">4.1. Subsetting</a></span>
#             <ul>
#                 <li><span><a href="#4.1.1.-By-collection" data-toc-modified-id="4.1.1.-By-collection">4.1.1. By collection</a></span></li>
#                 <li><span><a href="#4.1.2.-By-data-type" data-toc-modified-id="4.1.2.-By-data-type">4.1.2. By data type</a></span></li>
#                 <li><span><a href="#4.1.3.-By-file-type" data-toc-modified-id="4.1.3.-By-file-type">4.1.3. By file type</a></span></li>
#                 <li><span><a href="#4.1.4.-By-parameter" data-toc-modified-id="4.1.4.-By-parameter">4.1.4. By parameter</a></span></li>
#                 <li><span><a href="#4.1.5.-By-platform-code" data-toc-modified-id="4.1.5.-By-platform-code">4.1.5. By platform code</a></span></li>
#                 <li><span><a href="#4.1.6.-By-provider" data-toc-modified-id="4.1.6.-By-provider">4.1.6. By provider</a></span></li>
#                 <li><span><a href="#4.1.7.-By-several-criterias-at-once" data-toc-modified-id="4.1.7.By-several-criterias-at-once">4.1.7. By several criterias at once</a></span></li>
#             </ul>
#             </li>
#             <li><span><a href="#4.2.-Exporting" data-toc-modified-id="4.2.-Exporting">4.2. Exporting</a></span></li>
#             <li><span><a href="#4.3.-Downloading" data-toc-modified-id="4.3.-Downloading">4.3. Downloading</a></span></li>
#         </ul>
#         </li>
#         <li><span><a href="#5.-Wrap-up" data-toc-modified-id="5.-Wrap-up">5. Wrap-up</a></span></li>
#     </ul>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Introduction
# [Go back to the "Table of contents"](#Table-of-Contents)
#
# This notebook focuses on getting an overview of the content of a given In Situ dataset. Any In Situ dataset is just a bunch of netcdf files storing the measurements made by platforms (*drifters, profilers, gliders, moorings, HF-radars, vessels etc*) deployed in the ocean in order to monitor ocean state and variability.

# %% [markdown]
# | ![northern-america.gif](img/northern-america.gif)|
# |:--:|
# | *Last  location (point or trajectory) of the platforms providing near real time data in northern america since 1913* |

# %% [markdown]
# | ![centro-america.gif](img/centro-america.gif)|
# |:--:|
# | *Last  location (point or trajectory) of the platforms providing near real time data in centro america since 1913* |

# %% [markdown]
# | ![southern-america.gif](img/southern-america.gif)|
# |:--:|
# | *Last  location (point or trajectory) of the platforms providing near real time data in southern america since 1913* |

# %% [markdown]
# The files composing a dataset are grouped in `collections`, typically named: `latest`, `monthly` and/or `history`. To ease the exploration of these collections, users will find a set of `index files` describing the content of each one (`index_latest.txt`, `index_monthly.txt` and `index_history.txt`). In addition to these index files, it is also possible to find further info regarding each platform contributing with files to the dataset on the `index_platform.txt` when available.

# %% [markdown]
# | Index |  Description |
# | ------- | ----------- |
# | `index_latest.txt`  |  List of available files within the latest collection + metadata |
# | `index_monthly.txt`   | List of available files within the monthly collection + metadata |
# | `index_history.txt`   |  List of available files within the history collection + metadata |
# | `index_platform.txt`   | Full list of platforms + metadata |

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>OBJECTIVE</b>
#
# ***
# To select and download only netCDF files matching our needs from the whole original set of files that composes a specific dataset by using the aforementioned index files.
# </div>

# %% [markdown]
# ## 2. Setup
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# ### 2.1. Python packages

# %% [markdown]
# To properly run the notebook, we first need to load the next packages available from the Jupyter Notebook Ecosystem. Please run the `next cell`:

# %%
import warnings
warnings.filterwarnings("ignore")

import IPython
import pandas as pd
import datetime
import random
import os
import ftputil
from shapely.geometry import box, Point
import plotly.express as px

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If any of them raises any error it means you need to install the module first. For doing so please:
# 1. Open a new cell in the notebook
# 2. Run <i>`!conda install packageName --yes`</i> or <i>`!conda install -c conda-forge packageName --yes`</i> or <i>`!pip install packageName`</i>
# 3. Import again!
# <br><br>
# Example: <i>how-to-solve import error for json2html module </i>
#
# ![errorImporting.gif](img/errorImporting.gif)
# </div>

# %% [markdown]
# In addition to these packages, there are a set of Auxiliary Functions defined in the `/lib/functions.py` script that we are going to import too: `run the next cell`

# %%
import lib.functions as insitu

# %% [markdown]
# ### 2.2. Copernicus Database
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# Please `set next your CMEMS User credentials` in the next cell and `run the cell` afterwards:

# %%
usr = 'inputHereYourCMEMSuser'
pas = 'inputHereYourCMEMSpass'

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you have credentials yet?** <br>Please go [here](https://resources.marine.copernicus.eu/?option=com_sla) to get the above credentials to be able to access CMEMS secured FTP server.
# </div>

# %% [markdown]
#  As stated before, we will focus on exploring the content of a given In Situ product/dataset. By default we are going to explore the multiparameter dataset of the global region, but you are free to choose a different one.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>INFO</b>
#
# ***
# Find [here](tips/insitu-datasets-configurations.ipynb) the full list if In Situ dataset. Please, if you have the possibility to choose a regional product ("IBI", "NWS", "BAL", "ARC", "BS", "MED") instead if a global one (GLO), choose those better. They focus on certain [areas](https://www.seanoe.org/data/00333/44395/) and the amount of data will be always more manageable.
# </div>

# %% [markdown]
# After choosing, `copy the configuration on the next cell and run it`:

# %%
dataset = {
    'host': 'nrt.cmems-du.eu',
    'product': 'INSITU_GLO_NRT_OBSERVATIONS_013_030',
    'name': 'glo_multiparameter_nrt',
    'index_files': ['index_latest.txt', 'index_monthly.txt', 'index_history.txt'],
    'index_platform': 'index_platform.txt',
}

# %% [markdown]
# ### 2.3. Search constrains
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# As the dataset we are going to analyse covers way more that your area and times of interest, let's narrow it down a little bit by defining a:

# %% [markdown]
# - Area of interest

# %% [markdown]
# Set a bounding box of interest int he next cell and `run it`:

# %%
targeted_geospatial_lat_min = 10.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 25.0  # enter max latitude of your bounding box
targeted_geospatial_lon_min = -75.0 # enter min longitude of your bounding box
targeted_geospatial_lon_max = -55.0 # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %% [markdown]
# Let's get this polygon coords: `run the next cell`

# %%
upper_left = [targeted_geospatial_lon_min, targeted_geospatial_lat_max]
upper_right = [targeted_geospatial_lon_max, targeted_geospatial_lat_max]
lower_right = [targeted_geospatial_lon_max, targeted_geospatial_lat_min]
lower_left = [targeted_geospatial_lon_min, targeted_geospatial_lat_min]
coords = [upper_left, upper_right, lower_right, lower_left]

# %%
geojson = {
    "type": "FeatureCollection",
    "features":[{ 
    "type": "Feature",
    "geometry": {
        "type": "Polygon",
        "coordinates":  [coords]}
}]}
polygon=dict(sourcetype = 'geojson',source =geojson,below='', type = 'fill', color='blue', opacity=0.4)

# %% [markdown]
# Let's see it on a map: `run the next cell`

# %%
fig = px.scatter_mapbox(lat=[targeted_geospatial_lat_min], lon=[targeted_geospatial_lon_min], zoom=2, height=400, size=[0])
fig.layout.update(mapbox_layers =[polygon])
fig.update_layout(mapbox_style="open-street-map", margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning" style="margin-left: 2em">
# <b>Warning</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).

# %% [markdown]
# - Times of interest

# %% [markdown]
# Please `set the start/end dates` you are interested in `and run the cells bellow`:

# %%
targeted_range = '2020-01-01T00:00:00Z/2021-12-31T23:59:59Z' #set your own!

# %% [markdown]
# ## 3. Getting started
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# For the analysis to be carried out we need the most recent version of the index files. By default we will save them into the current working directory. Nevertheless if you rather use a different one, set it next:

# %%
path2indexes= os.getcwd()#default path to save the files
path2indexes
# Out:
# '/DATA/shared_trainers/training-AMERICA/05 Jupyter Notebook - In Situ Observation Products'

# %% [markdown]
# Please `Run the next` cell to download the index files:

# %%
insitu.getIndexFiles(usr,pas,dataset,path2indexes)
# Out:
# .....Downloading index_latest.txt
# .....Downloading index_monthly.txt
# .....Downloading index_history.txt
# .....Downloading index_platform.txt
# Ready!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Are you getting a `permission denied` error?**
# <br>Please be aware that no `writes` are authorized in the 'shared_notebook' folder. Make sure you run this on you own space after copying the notebooks form shared_notebooks. If you are still facing a problem contact us trough [Mattermost](https://chat-cmems.mercator-ocean.fr/).
# </div>

# %% [markdown]
# Let's load now the info contained in such files into a dataframe: `run the next cell!`

# %%
info = insitu.getIndexFilesInfo(dataset, path2indexes,targeted_bbox, targeted_range)
# Out:
# ...Loading info from: index_platform.txt
# ...Loading info from: index_latest.txt
# ...Loading info from: index_monthly.txt
# ...Loading info from: index_history.txt
# Ready!

# %% [markdown]
# `Run now the next cell` to see the information just loaded above:

# %%
info.transpose()
# Out:
#                                                                          0     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -31.0333
# geospatial_lat_max                                                    57.7027
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2021-06-01T00:00:00Z
# time_coverage_end                                        2021-06-01T23:50:00Z
# institution                                                               STE
# date_update                                              2021-06-07T19:01:20Z
# data_mode                                                                   R
# parameters                                      TEMP WDIR HCSP HCDT WSPD DEPH
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                   BO_TS_FB_StenaJutlandica_20210601.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          1     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -27.0333
# geospatial_lat_max                                                    57.7029
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2021-06-22T00:00:00Z
# time_coverage_end                                        2021-06-22T13:40:00Z
# institution                                                               STE
# date_update                                              2021-06-22T19:01:11Z
# data_mode                                                                   R
# parameters                                      TEMP WDIR HCSP HCDT WSPD DEPH
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                   BO_TS_FB_StenaJutlandica_20210622.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          2     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -26.8833
# geospatial_lat_max                                                    57.7035
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9426
# time_coverage_start                                      2020-03-01T00:00:00Z
# time_coverage_end                                        2020-03-23T10:30:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:47:11Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202003.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          3     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -32.0833
# geospatial_lat_max                                                    57.7029
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-04-01T00:00:00Z
# time_coverage_end                                        2020-04-30T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:47:20Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202004.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          4     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -28.2833
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-06-01T00:00:00Z
# time_coverage_end                                        2020-06-30T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:48:43Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202006.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          5     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -28.0833
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-07-01T00:00:00Z
# time_coverage_end                                        2020-07-31T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:48:50Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202007.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          6     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -24.3333
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-08-01T00:00:00Z
# time_coverage_end                                        2020-08-31T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:48:59Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202008.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          7     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -28.2667
# geospatial_lat_max                                                    57.7031
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9426
# time_coverage_start                                      2020-09-01T00:00:00Z
# time_coverage_end                                        2020-09-30T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:49:11Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202009.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          8     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -26.8667
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-10-01T00:00:00Z
# time_coverage_end                                        2020-10-31T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:49:52Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202010.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          9     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                      -25.5
# geospatial_lat_max                                                    57.7031
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-11-01T00:00:00Z
# time_coverage_end                                        2020-11-30T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:50:33Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202011.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# timeOverlap                 ...
# spatialOverlap              ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                          4027  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                      14.96
# geospatial_lat_max                                                    41.5585
# geospatial_lon_min                                                    121.046
# geospatial_lon_max                                                   -136.623
# time_coverage_start                                      2016-10-28T14:56:00Z
# time_coverage_end                                        2021-05-31T23:55:00Z
# institution                                               Unknown institution
# date_update                                              2021-06-07T02:48:28Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_DB_5201555.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         5201555
# wmo_platform_code                                                     5201555
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             33.2107
# last_longitude_observation                                           -156.864
# last_date_observation                                    2021-06-22T13:55:00Z
#
#                                                                          4028  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    22.1544
# geospatial_lat_max                                                    40.2924
# geospatial_lon_min                                                    123.834
# geospatial_lon_max                                                   -155.217
# time_coverage_start                                      2018-06-17T19:04:00Z
# time_coverage_end                                        2021-05-31T23:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-06-07T02:52:07Z
# data_mode                                                                   R
# parameters                                                     DEPH TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_DB_5300623.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         5300623
# wmo_platform_code                                                     5300623
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             34.3354
# last_longitude_observation                                           -154.943
# last_date_observation                                    2021-06-22T14:00:00Z
#
#                                                                          4029  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    1.36288
# geospatial_lat_max                                                    40.0849
# geospatial_lon_min                                                    122.127
# geospatial_lon_max                                                   -175.559
# time_coverage_start                                      2018-06-29T03:10:00Z
# time_coverage_end                                        2021-04-12T15:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-05-03T13:57:10Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_DB_5301531.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         5301531
# wmo_platform_code                                                     5301531
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             35.6304
# last_longitude_observation                                           -177.572
# last_date_observation                                    2021-04-12T15:00:00Z
#
#                                                                          4030  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    21.2345
# geospatial_lat_max                                                    44.8909
# geospatial_lon_min                                                   -62.6284
# geospatial_lon_max                                                   -16.0123
# time_coverage_start                                      2016-07-18T21:00:00Z
# time_coverage_end                                        2020-01-18T13:00:00Z
# institution                 Atlantic Oceanographic and Meteorological Labo...
# date_update                                              2020-02-03T23:11:34Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_DB_6200725.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         6200725
# wmo_platform_code                                                     6200725
# institution_edmo_code                                                    1799
# last_latitude_observation                                             32.8341
# last_longitude_observation                                            -49.991
# last_date_observation                                    2020-01-18T13:00:00Z
#
#                                                                          4031  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    15.0804
# geospatial_lat_max                                                    39.5419
# geospatial_lon_min                                                   -78.9521
# geospatial_lon_max                                                    -34.506
# time_coverage_start                                      2017-11-29T12:41:00Z
# time_coverage_end                                        2021-05-03T21:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-06-07T03:22:39Z
# data_mode                                                                   R
# parameters                                                     DEPH TEMP ATMS
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_DB_6203529.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         6203529
# wmo_platform_code                                                     6203529
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             32.5573
# last_longitude_observation                                           -38.2673
# last_date_observation                                    2021-05-03T21:00:00Z
#
#                                                                          4032  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    22.3505
# geospatial_lat_max                                                    36.4888
# geospatial_lon_min                                                   -76.5806
# geospatial_lon_max                                                   -58.1511
# time_coverage_start                                      2019-02-12T02:47:00Z
# time_coverage_end                                        2021-03-13T23:58:00Z
# institution                                               Unknown institution
# date_update                                              2021-04-05T08:19:22Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_DB_6203706.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         6203706
# wmo_platform_code                                                     6203706
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             35.2021
# last_longitude_observation                                           -70.4811
# last_date_observation                                    2021-03-13T23:58:00Z
#
#                                                                          4033  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    13.9118
# geospatial_lat_max                                                    45.6984
# geospatial_lon_min                                                   -157.954
# geospatial_lon_max                                                    18.9468
# time_coverage_start                                      2018-10-03T20:00:00Z
# time_coverage_end                                        2020-07-17T11:59:00Z
# institution                                                         Saildrone
# date_update                                              2021-06-16T15:06:31Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL CNDC ATMP ATMS CHLT DRYT GSPD L...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_SD_5801955.nc
# file_type                                                                  TS
# data_type                                                                  SD
# platform_code                                                         5801955
# wmo_platform_code                                                     5801955
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             45.6931
# last_longitude_observation                                            13.7096
# last_date_observation                                    2020-07-17T11:59:00Z
#
#                                                                          4034  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     4.0855
# geospatial_lat_max                                                    60.2113
# geospatial_lon_min                                                     -80.12
# geospatial_lon_max                                                    30.2223
# time_coverage_start                                      2002-04-13T05:00:00Z
# time_coverage_end                                        2021-05-31T22:10:00Z
# institution                 IRD Institut de recherche pour le developpemen...
# date_update                                              2021-06-07T04:17:49Z
# data_mode                                                                   M
# parameters                  DEPH PSAL PSAL_ADJUSTED PSAL_ADJUSTED_ERROR CN...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_TS_TS_FNAV.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            FNAV
# wmo_platform_code                                                        FNAV
# institution_edmo_code                                                     440
# last_latitude_observation                                                51.9
# last_longitude_observation                                             4.2333
# last_date_observation                                    2021-06-21T21:55:00Z
#
#                                                                          4035  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    4.84833
# geospatial_lat_max                                                     71.749
# geospatial_lon_min                                                     -80.12
# geospatial_lon_max                                                    30.2248
# time_coverage_start                                      2001-12-21T22:48:00Z
# time_coverage_end                                        2021-05-31T12:56:00Z
# institution                 IRD Institut de recherche pour le developpemen...
# date_update                                              2021-06-07T06:03:53Z
# data_mode                                                                   M
# parameters                  DEPH PSAL PSAL_ADJUSTED PSAL_ADJUSTED_ERROR CN...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_TS_TS_FNHO.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            FNHO
# wmo_platform_code                                                        FNHO
# institution_edmo_code                                                     440
# last_latitude_observation                                             43.3167
# last_longitude_observation                                               5.35
# last_date_observation                                    2021-06-18T13:55:00Z
#
#                                                                          4036
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     14.388
# geospatial_lat_max                                                    44.5485
# geospatial_lon_min                                                   -97.2063
# geospatial_lon_max                                                   -50.9151
# time_coverage_start                                      2009-11-12T18:28:28Z
# time_coverage_end                                        2021-05-30T23:56:40Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-07T09:29:07Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL CNDC SSJT
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_TS_TS_WTDL.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTDL
# wmo_platform_code                                                        WTDL
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             29.4481
# last_longitude_observation                                           -80.3214
# last_date_observation                                    2021-06-11T23:55:42Z
#
# [23 rows x 4037 columns]

# %% [markdown]
# Above you can see, on the left hand side, a number of metadata fields that describes the files available in each collection (latest, monthly and history) of the dataset chosen, such as: ftplink to download it (file_name), geospatial bounding box (geospatial_lat/lon_min/max), temporal coverage (time_coverage_start/end) etc. You can also see a dedicated column for each file with its corresponding values for the aforementioned descriptive metadata fields.

# %% [markdown]
# One of the most important fields in the above info is the `file_name`. This field contains the full path to the file in the FTP server, saving users from having to know the actual FTP structure. As the above preview does not render such field completely, let's see the first file full path: `Run the next cell`

# %%
info['file_name'].tolist()[0]
# Out:
# 'ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSERVATIONS_013_030/glo_multiparameter_nrt/latest/20210601/BO_TS_FB_StenaJutlandica_20210601.nc'

# %% [markdown]
# Copy the path into the browser....the file will download straightaway!<br>
# Next we will aim:
# <ul><li>the `file_name` field (file path) for downloading operations</li>
#     <li> the other fileds (file metadata) for the subsetting operations</li>
# </ul>

# %% [markdown]
# ## 4. Operations
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# ### 4.1. Subsetting

# %% [markdown]
# Prior to <i>download</i> we need to select only those netCDF files that are of our interest.<br>There are many different criterias (if files contain a certain parameter, if they cover a certain area or/and a specific time range....).<br>Next we will see some examples!

# %% [markdown]
# #### 4.1.1. By collection

# %% [markdown]
# Let's select only the files that belong to one specific collection!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# Please remember available options:
# <ul>
#     <li><i>latest</i>: daily files from platforms (last 30 days of data)</li>
#     <li><i>monthly</i>: monthly files from platforms (last 5 years of data)</li>
#     <li><i>history</i>: one file per platform (all platform data)</li>
# </ul>
# </div>

# %% [markdown]
# `Set one collection` next and `run the cells`:

# %%
targeted_collection = 'monthly' #try 'latest', 'monthly' or 'history'

# %%
condition = info['file_name'].str.contains(targeted_collection)
subset = info[condition]
subset.transpose()
# Out:
#                                                                          2     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -26.8833
# geospatial_lat_max                                                    57.7035
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9426
# time_coverage_start                                      2020-03-01T00:00:00Z
# time_coverage_end                                        2020-03-23T10:30:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:47:11Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202003.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          3     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -32.0833
# geospatial_lat_max                                                    57.7029
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-04-01T00:00:00Z
# time_coverage_end                                        2020-04-30T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:47:20Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202004.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          4     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -28.2833
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-06-01T00:00:00Z
# time_coverage_end                                        2020-06-30T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:48:43Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202006.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          5     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -28.0833
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-07-01T00:00:00Z
# time_coverage_end                                        2020-07-31T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:48:50Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202007.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          6     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -24.3333
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-08-01T00:00:00Z
# time_coverage_end                                        2020-08-31T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:48:59Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202008.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          7     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -28.2667
# geospatial_lat_max                                                    57.7031
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9426
# time_coverage_start                                      2020-09-01T00:00:00Z
# time_coverage_end                                        2020-09-30T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:49:11Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202009.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          8     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -26.8667
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-10-01T00:00:00Z
# time_coverage_end                                        2020-10-31T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:49:52Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202010.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          9     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                      -25.5
# geospatial_lat_max                                                    57.7031
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9425
# time_coverage_start                                      2020-11-01T00:00:00Z
# time_coverage_end                                        2020-11-30T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:50:33Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202011.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          10    \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                      -28.1
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9426
# time_coverage_start                                      2021-01-01T00:00:00Z
# time_coverage_end                                        2021-01-31T23:50:00Z
# institution                                                               STE
# date_update                                              2021-02-07T02:51:56Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP WDIR HCSP HCDT WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202101.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                                                                          11    \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     -25.35
# geospatial_lat_max                                                     57.703
# geospatial_lon_min                                                       -999
# geospatial_lon_max                                                    11.9426
# time_coverage_start                                      2021-02-01T00:00:00Z
# time_coverage_end                                        2021-02-28T23:50:00Z
# institution                                                               STE
# date_update                                              2021-03-01T07:03:48Z
# data_mode                                                                   R
# parameters                                      TEMP WDIR HCSP HCDT WSPD DEPH
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                     BO_TS_FB_StenaJutlandica_202102.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                 StenaJutlandica
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1218
# last_latitude_observation                                             57.7012
# last_longitude_observation                                            11.9377
# last_date_observation                                    2021-06-22T07:40:00Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# timeOverlap                 ...
# spatialOverlap              ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                          3843  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    24.0275
# geospatial_lat_max                                                    36.8002
# geospatial_lon_min                                                   -88.5205
# geospatial_lon_max                                                   -74.9525
# time_coverage_start                                      2020-10-21T18:25:06Z
# time_coverage_end                                        2020-10-30T23:55:35Z
# institution                                           United states (Unknown)
# date_update                                              2020-11-03T13:40:43Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL CNDC SSJT
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTDH_202010.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTDH
# wmo_platform_code                                                        WTDH
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              40.424
# last_longitude_observation                                            -70.722
# last_date_observation                                    2021-06-21T15:38:00Z
#
#                                                                          3846  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    12.9778
# geospatial_lat_max                                                    15.8639
# geospatial_lon_min                                                   -59.9062
# geospatial_lon_max                                                   -50.9248
# time_coverage_start                                      2020-01-06T17:50:18Z
# time_coverage_end                                        2020-01-31T23:55:57Z
# institution                                              NOAA sponsored ships
# date_update                                              2020-07-20T12:54:10Z
# data_mode                                                                   R
# parameters                                                DEPH SSJT CNDC PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTEC_202001.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTEC
# wmo_platform_code                                                        WTEC
# institution_edmo_code                                                    3589
# last_latitude_observation                                             36.6616
# last_longitude_observation                                           -121.908
# last_date_observation                                    2021-06-19T23:43:42Z
#
#                                                                          3847  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -5.60532
# geospatial_lat_max                                                     14.638
# geospatial_lon_min                                                   -59.6657
# geospatial_lon_max                                                   -25.7581
# time_coverage_start                                      2020-02-01T00:01:57Z
# time_coverage_end                                        2020-02-29T23:56:08Z
# institution                                              NOAA sponsored ships
# date_update                                              2020-07-20T12:54:10Z
# data_mode                                                                   R
# parameters                                                DEPH SSJT CNDC PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTEC_202002.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTEC
# wmo_platform_code                                                        WTEC
# institution_edmo_code                                                    3589
# last_latitude_observation                                             36.6616
# last_longitude_observation                                           -121.908
# last_date_observation                                    2021-06-19T23:43:42Z
#
#                                                                          3848  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -19.0385
# geospatial_lat_max                                                    36.9151
# geospatial_lon_min                                                   -75.9063
# geospatial_lon_max                                                   -16.1874
# time_coverage_start                                      2020-04-01T00:01:59Z
# time_coverage_end                                        2020-04-17T12:49:55Z
# institution                                              NOAA sponsored ships
# date_update                                              2020-07-20T12:54:10Z
# data_mode                                                                   R
# parameters                                                DEPH SSJT CNDC PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTEC_202004.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTEC
# wmo_platform_code                                                        WTEC
# institution_edmo_code                                                    3589
# last_latitude_observation                                             36.6616
# last_longitude_observation                                           -121.908
# last_date_observation                                    2021-06-19T23:43:42Z
#
#                                                                          3849  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     13.694
# geospatial_lat_max                                                     36.986
# geospatial_lon_min                                                   -79.7645
# geospatial_lon_max                                                   -50.9111
# time_coverage_start                                      2020-10-10T22:23:51Z
# time_coverage_end                                        2020-10-31T22:59:09Z
# institution                                              NOAA sponsored ships
# date_update                                              2020-11-04T13:01:23Z
# data_mode                                                                   R
# parameters                                                DEPH PSAL CNDC SSJT
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTEC_202010.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTEC
# wmo_platform_code                                                        WTEC
# institution_edmo_code                                                    3589
# last_latitude_observation                                             36.6616
# last_longitude_observation                                           -121.908
# last_date_observation                                    2021-06-19T23:43:42Z
#
#                                                                          3850  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    15.4338
# geospatial_lat_max                                                    26.9549
# geospatial_lon_min                                                   -80.1018
# geospatial_lon_max                                                   -51.4869
# time_coverage_start                                      2020-12-01T00:01:57Z
# time_coverage_end                                        2020-12-20T16:07:38Z
# institution                                              NOAA sponsored ships
# date_update                                              2021-01-08T12:38:08Z
# data_mode                                                                   R
# parameters                                                DEPH PSAL CNDC SSJT
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTEC_202012.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTEC
# wmo_platform_code                                                        WTEC
# institution_edmo_code                                                    3589
# last_latitude_observation                                             36.6616
# last_longitude_observation                                           -121.908
# last_date_observation                                    2021-06-19T23:43:42Z
#
#                                                                          3851  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    13.9873
# geospatial_lat_max                                                    26.3467
# geospatial_lon_min                                                   -80.0414
# geospatial_lon_max                                                   -22.5667
# time_coverage_start                                      2021-01-15T16:17:03Z
# time_coverage_end                                        2021-01-31T23:55:59Z
# institution                                              NOAA sponsored ships
# date_update                                              2021-02-04T13:12:50Z
# data_mode                                                                   R
# parameters                                                DEPH PSAL CNDC SSJT
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTEC_202101.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTEC
# wmo_platform_code                                                        WTEC
# institution_edmo_code                                                    3589
# last_latitude_observation                                             36.6616
# last_longitude_observation                                           -121.908
# last_date_observation                                    2021-06-19T23:43:42Z
#
#                                                                          3852  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -3.99663
# geospatial_lat_max                                                    26.3502
# geospatial_lon_min                                                   -81.8033
# geospatial_lon_max                                                   -22.9791
# time_coverage_start                                      2021-02-01T00:01:59Z
# time_coverage_end                                        2021-02-24T15:04:46Z
# institution                                              NOAA sponsored ships
# date_update                                              2021-03-01T18:41:22Z
# data_mode                                                                   R
# parameters                                                DEPH PSAL CNDC SSJT
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTEC_202102.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTEC
# wmo_platform_code                                                        WTEC
# institution_edmo_code                                                    3589
# last_latitude_observation                                             36.6616
# last_longitude_observation                                           -121.908
# last_date_observation                                    2021-06-19T23:43:42Z
#
#                                                                          3853  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    15.2383
# geospatial_lat_max                                                    21.4117
# geospatial_lon_min                                                    150.549
# geospatial_lon_max                                                   -156.707
# time_coverage_start                                      2021-04-07T12:55:28Z
# time_coverage_end                                        2021-04-30T23:56:18Z
# institution                                         US DOC NOAA NMFS HONOLULU
# date_update                                              2021-05-04T14:34:22Z
# data_mode                                                                   R
# parameters                                                DEPH TEMP PSAL CNDC
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTEE_202104.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTEE
# wmo_platform_code                                                        WTEE
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              16.066
# last_longitude_observation                                            147.768
# last_date_observation                                    2021-06-19T23:55:58Z
#
#                                                                          3855
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    24.2699
# geospatial_lat_max                                                    41.5234
# geospatial_lon_min                                                   -87.7802
# geospatial_lon_max                                                   -71.3353
# time_coverage_start                                      2021-05-01T00:01:37Z
# time_coverage_end                                        2021-05-13T11:43:50Z
# institution                 National Marine Fisheries Service Mississippi ...
# date_update                                              2021-06-01T18:23:17Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL CNDC SSJT
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                GL_TS_TS_WTEO_202105.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTEO
# wmo_platform_code                                                        WTEO
# institution_edmo_code                                                    4476
# last_latitude_observation                                             36.6457
# last_longitude_observation                                           -73.0827
# last_date_observation                                    2021-06-19T23:55:55Z
#
# [23 rows x 1870 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"">
# <b>TIP</b>
#
# ***
# To check if the above output only lists the files coming from a certain collection (the one set as targeted_collection') just check the `netcdf` row
# <ul><li>'latest' timestamp: netcdf file name ends with a YYYYMMDD</li>
#  <li>'monthly' timestamp: netcdf file name ends with a YYYYMM</li>
# <li>'history' timestamp: netcdf file name ends with a YYYY or none timestamp</li></ul>
# </div>

# %% [markdown]
# #### 4.1.2. By data type
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# Let's look for files produced by a certain data type.<br>`Please set a data type` next `and run the cell`:

# %%
targeted_data_type = 'PF' # try others: TG for Tide Gauges, PF for profilers etc =>Product User Manual: https://archimer.ifremer.fr/doc/00324/43494/

# %% [markdown]
# `Run the next cell` to obtain just the files reported by such data type:

# %%
condition = info['data_type'] == targeted_data_type
subset = info[condition]
subset.transpose()
# Out:
#                                                                          414   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    23.0389
# geospatial_lat_max                                                    23.0389
# geospatial_lon_min                                                   -62.8536
# geospatial_lon_max                                                   -62.8536
# time_coverage_start                                      2021-06-01T20:08:01Z
# time_coverage_end                                        2021-06-01T20:08:01Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-06-12T01:01:37Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                           GL_PR_PF_1902299_20210601.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1902299
# wmo_platform_code                                                     1902299
# institution_edmo_code                                                    3844
# last_latitude_observation                                             22.9483
# last_longitude_observation                                           -63.0105
# last_date_observation                                    2021-06-21T14:31:14Z
#
#                                                                          415   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    22.9961
# geospatial_lat_max                                                    22.9961
# geospatial_lon_min                                                   -62.9753
# geospatial_lon_max                                                   -62.9753
# time_coverage_start                                      2021-06-11T17:19:54Z
# time_coverage_end                                        2021-06-11T17:19:54Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-06-21T20:01:43Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                           GL_PR_PF_1902299_20210611.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1902299
# wmo_platform_code                                                     1902299
# institution_edmo_code                                                    3844
# last_latitude_observation                                             22.9483
# last_longitude_observation                                           -63.0105
# last_date_observation                                    2021-06-21T14:31:14Z
#
#                                                                          416   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    22.9483
# geospatial_lat_max                                                    22.9483
# geospatial_lon_min                                                   -63.0105
# geospatial_lon_max                                                   -63.0105
# time_coverage_start                                      2021-06-21T14:31:14Z
# time_coverage_end                                        2021-06-21T14:31:14Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-06-21T20:01:46Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                           GL_PR_PF_1902299_20210621.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1902299
# wmo_platform_code                                                     1902299
# institution_edmo_code                                                    3844
# last_latitude_observation                                             22.9483
# last_longitude_observation                                           -63.0105
# last_date_observation                                    2021-06-21T14:31:14Z
#
#                                                                          417   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    21.6432
# geospatial_lat_max                                                    21.7756
# geospatial_lon_min                                                   -64.0164
# geospatial_lon_max                                                   -63.9989
# time_coverage_start                                      2021-01-19T16:29:38Z
# time_coverage_end                                        2021-01-24T09:48:24Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-02-03T12:05:30Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_PF_1902299_202101.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1902299
# wmo_platform_code                                                     1902299
# institution_edmo_code                                                    3844
# last_latitude_observation                                             22.9483
# last_longitude_observation                                           -63.0105
# last_date_observation                                    2021-06-21T14:31:14Z
#
#                                                                          418   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    21.1499
# geospatial_lat_max                                                    21.3647
# geospatial_lon_min                                                   -64.1622
# geospatial_lon_max                                                   -64.0533
# time_coverage_start                                      2021-02-03T06:58:01Z
# time_coverage_end                                        2021-02-23T01:11:48Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-03-05T12:10:45Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_PF_1902299_202102.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1902299
# wmo_platform_code                                                     1902299
# institution_edmo_code                                                    3844
# last_latitude_observation                                             22.9483
# last_longitude_observation                                           -63.0105
# last_date_observation                                    2021-06-21T14:31:14Z
#
#                                                                          419   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    21.8264
# geospatial_lat_max                                                    22.5129
# geospatial_lon_min                                                   -64.3054
# geospatial_lon_max                                                   -64.0137
# time_coverage_start                                      2021-03-04T22:17:28Z
# time_coverage_end                                        2021-03-24T16:33:47Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-04-04T12:05:19Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_PF_1902299_202103.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1902299
# wmo_platform_code                                                     1902299
# institution_edmo_code                                                    3844
# last_latitude_observation                                             22.9483
# last_longitude_observation                                           -63.0105
# last_date_observation                                    2021-06-21T14:31:14Z
#
#                                                                          420   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    22.0899
# geospatial_lat_max                                                    22.5836
# geospatial_lon_min                                                   -64.3321
# geospatial_lon_max                                                   -62.9875
# time_coverage_start                                      2021-04-03T13:38:34Z
# time_coverage_end                                        2021-04-23T07:52:15Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-05-03T12:04:40Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_PF_1902299_202104.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1902299
# wmo_platform_code                                                     1902299
# institution_edmo_code                                                    3844
# last_latitude_observation                                             22.9483
# last_longitude_observation                                           -63.0105
# last_date_observation                                    2021-06-21T14:31:14Z
#
#                                                                          421   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    22.2817
# geospatial_lat_max                                                    22.9438
# geospatial_lon_min                                                    -62.614
# geospatial_lon_max                                                   -62.4482
# time_coverage_start                                      2021-05-03T04:59:00Z
# time_coverage_end                                        2021-05-22T23:00:18Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-06-02T12:07:38Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_PF_1902299_202105.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1902299
# wmo_platform_code                                                     1902299
# institution_edmo_code                                                    3844
# last_latitude_observation                                             22.9483
# last_longitude_observation                                           -63.0105
# last_date_observation                                    2021-06-21T14:31:14Z
#
#                                                                          422   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    21.1499
# geospatial_lat_max                                                    22.9438
# geospatial_lon_min                                                   -64.3321
# geospatial_lon_max                                                   -62.4482
# time_coverage_start                                      2021-01-19T16:29:38Z
# time_coverage_end                                        2021-05-22T23:00:18Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-06-06T07:22:29Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_1902299.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1902299
# wmo_platform_code                                                     1902299
# institution_edmo_code                                                    3844
# last_latitude_observation                                             22.9483
# last_longitude_observation                                           -63.0105
# last_date_observation                                    2021-06-21T14:31:14Z
#
#                                                                          423   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    19.7383
# geospatial_lat_max                                                    19.7383
# geospatial_lon_min                                                    -58.239
# geospatial_lon_max                                                    -58.239
# time_coverage_start                                      2021-05-26T23:16:02Z
# time_coverage_end                                        2021-05-26T23:16:02Z
# institution                       Woods Hole Oceanographic Institution (WHOI)
# date_update                                              2021-05-27T01:01:20Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                           GL_PR_PF_3901037_20210526.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901037
# wmo_platform_code                                                     3901037
# institution_edmo_code                                                    3844
# last_latitude_observation                                             19.7383
# last_longitude_observation                                            -58.239
# last_date_observation                                    2021-05-26T23:16:02Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# timeOverlap                 ...
# spatialOverlap              ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                          3911  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     11.577
# geospatial_lat_max                                                     16.813
# geospatial_lon_min                                                    162.649
# geospatial_lon_max                                                   -177.682
# time_coverage_start                                      2015-01-04T06:29:30Z
# time_coverage_end                                        2021-05-27T09:56:19Z
# institution                 CSIRO Commonwealth Scientific and Industrial R...
# date_update                                              2021-06-06T15:43:45Z
# data_mode                                                                   M
# parameters                  PRES PRES_ADJUSTED PRES_ADJUSTED_ERROR TEMP TE...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_5904912.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         5904912
# wmo_platform_code                                                     5904912
# institution_edmo_code                                                    1484
# last_latitude_observation                                              14.057
# last_longitude_observation                                            176.568
# last_date_observation                                    2021-06-15T22:53:43Z
#
#                                                                          3912  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                       15.4
# geospatial_lat_max                                                     23.695
# geospatial_lon_min                                                    179.481
# geospatial_lon_max                                                   -153.087
# time_coverage_start                                      2016-05-03T22:00:45Z
# time_coverage_end                                        2021-02-07T22:47:07Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2021-03-02T00:13:16Z
# data_mode                                                                   M
# parameters                  PRES PRES_ADJUSTED PRES_ADJUSTED_ERROR TEMP TE...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_5905047.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         5905047
# wmo_platform_code                                                     5905047
# institution_edmo_code                                                    1537
# last_latitude_observation                                              18.417
# last_longitude_observation                                           -154.721
# last_date_observation                                    2021-02-07T22:47:07Z
#
#                                                                          3913  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    19.2707
# geospatial_lat_max                                                    21.4139
# geospatial_lon_min                                                    170.706
# geospatial_lon_max                                                   -179.974
# time_coverage_start                                      2019-04-05T14:12:13Z
# time_coverage_end                                        2021-05-22T03:58:37Z
# institution                 Scripps Institution of Oceanography La Jolla (...
# date_update                                              2021-06-06T18:39:26Z
# data_mode                                                                   M
# parameters                  PRES PRES_ADJUSTED PRES_ADJUSTED_ERROR TEMP TE...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_5905792.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         5905792
# wmo_platform_code                                                     5905792
# institution_edmo_code                                                    1390
# last_latitude_observation                                             19.9502
# last_longitude_observation                                             173.87
# last_date_observation                                    2021-06-20T23:15:39Z
#
#                                                                          3914  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     13.794
# geospatial_lat_max                                                     17.161
# geospatial_lon_min                                                    178.221
# geospatial_lon_max                                                   -169.718
# time_coverage_start                                      2019-05-07T02:07:28Z
# time_coverage_end                                        2021-04-23T04:50:18Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2021-05-25T07:38:45Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_5905862.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         5905862
# wmo_platform_code                                                     5905862
# institution_edmo_code                                                    1537
# last_latitude_observation                                              14.133
# last_longitude_observation                                           -168.404
# last_date_observation                                    2021-06-12T00:48:02Z
#
#                                                                          3915  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    23.4788
# geospatial_lat_max                                                    34.2843
# geospatial_lon_min                                                   -69.6995
# geospatial_lon_max                                                   -56.4193
# time_coverage_start                                      2012-11-13T17:46:22Z
# time_coverage_end                                        2021-05-30T21:22:08Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-06-06T19:39:47Z
# data_mode                                                                   M
# parameters                  PRES PRES_ADJUSTED PRES_ADJUSTED_ERROR TEMP TE...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_6901144.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901144
# wmo_platform_code                                                     6901144
# institution_edmo_code                                                      29
# last_latitude_observation                                             29.7316
# last_longitude_observation                                           -71.5731
# last_date_observation                                    2021-06-19T21:34:48Z
#
#                                                                          3916  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     24.142
# geospatial_lat_max                                                    28.9521
# geospatial_lon_min                                                    -56.829
# geospatial_lon_max                                                    -39.872
# time_coverage_start                                      2012-11-10T17:01:43Z
# time_coverage_end                                        2021-05-27T18:08:36Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-06-10T14:33:17Z
# data_mode                                                                   M
# parameters                  PRES PRES_ADJUSTED PRES_ADJUSTED_ERROR TEMP TE...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_6901145.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901145
# wmo_platform_code                                                     6901145
# institution_edmo_code                                                      29
# last_latitude_observation                                             26.5921
# last_longitude_observation                                           -40.1633
# last_date_observation                                    2021-06-16T18:26:25Z
#
#                                                                          3917  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    21.1396
# geospatial_lat_max                                                    29.0914
# geospatial_lon_min                                                   -72.8502
# geospatial_lon_max                                                   -60.6632
# time_coverage_start                                      2015-12-26T20:13:00Z
# time_coverage_end                                        2020-09-10T16:05:00Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-06-10T14:36:14Z
# data_mode                                                                   M
# parameters                  PRES PRES_ADJUSTED PRES_ADJUSTED_ERROR TEMP TE...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_6901183.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901183
# wmo_platform_code                                                     6901183
# institution_edmo_code                                                      29
# last_latitude_observation                                             27.8977
# last_longitude_observation                                           -60.6632
# last_date_observation                                    2020-09-10T16:05:00Z
#
#                                                                          3918  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    23.1598
# geospatial_lat_max                                                     30.328
# geospatial_lon_min                                                   -60.0864
# geospatial_lon_max                                                   -53.3345
# time_coverage_start                                      2017-03-22T23:45:43Z
# time_coverage_end                                        2021-05-31T02:20:31Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-06-06T19:46:51Z
# data_mode                                                                   M
# parameters                  PRES PRES_ADJUSTED PRES_ADJUSTED_ERROR TEMP TE...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_6901195.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901195
# wmo_platform_code                                                     6901195
# institution_edmo_code                                                      29
# last_latitude_observation                                             29.0977
# last_longitude_observation                                           -53.4938
# last_date_observation                                    2021-06-20T02:12:59Z
#
#                                                                          3919  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                      12.76
# geospatial_lat_max                                                     21.554
# geospatial_lon_min                                                    -84.177
# geospatial_lon_max                                                    -72.033
# time_coverage_start                                      2017-01-03T01:00:00Z
# time_coverage_end                                        2021-01-25T00:08:00Z
# institution                 SHOM Service Hydrographique et Oceanographique...
# date_update                                              2021-03-20T22:53:04Z
# data_mode                                                                   M
# parameters                  PRES PRES_ADJUSTED PRES_ADJUSTED_ERROR TEMP TE...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_6902712.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6902712
# wmo_platform_code                                                     6902712
# institution_edmo_code                                                     540
# last_latitude_observation                                              21.554
# last_longitude_observation                                            -84.177
# last_date_observation                                    2021-01-25T00:08:00Z
#
#                                                                          3920
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                      13.91
# geospatial_lat_max                                                     25.143
# geospatial_lon_min                                                    -85.606
# geospatial_lon_max                                                     -56.84
# time_coverage_start                                      2017-07-06T14:49:00Z
# time_coverage_end                                        2020-07-27T07:34:00Z
# institution                 IFREMER Institut Francais de Recherche pour l'...
# date_update                                              2020-09-07T09:48:14Z
# data_mode                                                                   M
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_PR_PF_6902746.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6902746
# wmo_platform_code                                                     6902746
# institution_edmo_code                                                    1054
# last_latitude_observation                                              25.143
# last_longitude_observation                                            -80.071
# last_date_observation                                    2020-07-27T07:34:00Z
#
# [23 rows x 763 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset only contains the aimed data type (targeted_data_type) just check the `data_type` row of the above output.
# </div>

# %% [markdown]
# #### 4.1.3. By file type
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# Let's look for certain types of files.<br>`Please set a file type` next `and run the cell`:

# %%
targeted_file_type = 'TS' # try others: RV for HF Radar radial velocities...=>Product User Manual: https://archimer.ifremer.fr/doc/00324/43494/

# %% [markdown]
# `Run the next cell` to obtain just the above type of files:

# %%
condition = info['file_type'] == targeted_file_type
subset = info[condition]
subset.transpose()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed file type (targeted_file_type) just check the `file_type` row of the above output.
# </div>

# %% [markdown]
# #### 4.1.4. By parameter
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# Let's look for files containing a certain parameter.<br>`Please set a parameter code` next `and run the cell`:

# %%
targeted_parameter = 'PSAL' #try others: TEMP, SLEV etc => In Situ parameter list: https://archimer.ifremer.fr/doc/00422/53381/

# %% [markdown]
# Run the next cell to obtain just the files reporting such parameter:

# %%
condition = info['parameters'].str.contains(targeted_parameter)
subset = info[condition]
subset.transpose()
# Out:
#                                                                          17    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-05-23T00:00:00Z
# time_coverage_end                                        2021-05-23T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-05-27T11:02:26Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210523.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          18    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-05-24T00:00:00Z
# time_coverage_end                                        2021-05-24T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-05-27T11:02:29Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210524.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          19    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-05-25T00:00:00Z
# time_coverage_end                                        2021-05-25T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-05-27T12:01:35Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210525.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          20    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-05-26T00:00:00Z
# time_coverage_end                                        2021-05-26T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-05-29T10:01:33Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210526.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          21    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-05-27T00:00:00Z
# time_coverage_end                                        2021-05-27T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-05-29T10:01:34Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210527.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          22    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-05-28T00:00:00Z
# time_coverage_end                                        2021-05-28T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-01T11:02:15Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210528.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          23    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-05-29T00:00:00Z
# time_coverage_end                                        2021-05-29T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-01T11:02:17Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210529.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          24    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-05-30T00:00:00Z
# time_coverage_end                                        2021-05-30T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-01T11:02:19Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210530.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          25    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-05-31T00:00:00Z
# time_coverage_end                                        2021-05-31T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-03T11:02:15Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210531.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          26    \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.249
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2021-06-01T00:00:00Z
# time_coverage_end                                        2021-06-01T23:00:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-03T11:02:17Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                             GL_PR_CT_41052_20210601.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# timeOverlap                 ...
# spatialOverlap              ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                          3921  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                      -2.13
# geospatial_lat_max                                                      45.82
# geospatial_lon_min                                                     115.92
# geospatial_lon_max                                                    -157.18
# time_coverage_start                                      1957-10-05T18:00:00Z
# time_coverage_end                                        2021-05-29T07:04:00Z
# institution                                            Maritime Safety Agency
# date_update                                              2021-06-06T23:42:17Z
# data_mode                                                                   R
# parameters                                      DEPH PRES TEMP PSAL HCDT HCSP
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_PR_XB_7JWN.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                            7JWN
# wmo_platform_code                                                        7JWN
# institution_edmo_code                                                    1980
# last_latitude_observation                                              30.003
# last_longitude_observation                                            138.576
# last_date_observation                                    2021-06-15T08:39:00Z
#
#                                                                          3927  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -39.7861
# geospatial_lat_max                                                    78.9597
# geospatial_lon_min                                                   -69.7223
# geospatial_lon_max                                                    71.4079
# time_coverage_start                                      2006-01-14T17:26:00Z
# time_coverage_end                                        2021-05-31T11:48:37Z
# institution                 IFREMER Institut Francais de Recherche pour l'...
# date_update                                              2021-06-06T23:42:16Z
# data_mode                                                                   R
# parameters                                                DEPH PRES TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_PR_XB_FMCY.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                            FMCY
# wmo_platform_code                                                        FMCY
# institution_edmo_code                                                    1054
# last_latitude_observation                                            -16.8433
# last_longitude_observation                                            52.6301
# last_date_observation                                    2021-06-04T04:12:28Z
#
#                                                                          3928  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                   -19.8302
# geospatial_lat_max                                                    67.1867
# geospatial_lon_min                                                   -66.7933
# geospatial_lon_max                                                    10.9994
# time_coverage_start                                      1968-08-21T20:30:00Z
# time_coverage_end                                        2021-04-10T10:07:06Z
# institution                 IFREMER Institut Francais de Recherche pour l'...
# date_update                                              2021-05-03T07:47:12Z
# data_mode                                                                   R
# parameters                                                     DEPH TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_PR_XB_FNFP.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                            FNFP
# wmo_platform_code                                                        FNFP
# institution_edmo_code                                                    1054
# last_latitude_observation                                             43.0956
# last_longitude_observation                                            5.91843
# last_date_observation                                    2021-06-20T15:36:11Z
#
#                                                                          3929  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                        -15
# geospatial_lat_max                                                      50.03
# geospatial_lon_min                                                     122.33
# geospatial_lon_max                                                   -140.502
# time_coverage_start                                      1969-08-14T11:39:00Z
# time_coverage_end                                        2021-02-24T01:38:00Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2021-04-18T06:39:02Z
# data_mode                                                                   R
# parameters                                                     DEPH TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_PR_XB_JDSS.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                            JDSS
# wmo_platform_code                                                        JDSS
# institution_edmo_code                                                    1537
# last_latitude_observation                                             33.1167
# last_longitude_observation                                              132.1
# last_date_observation                                    2021-03-01T23:00:00Z
#
#                                                                          3972  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    24.3282
# geospatial_lat_max                                                    51.9703
# geospatial_lon_min                                                   -79.2468
# geospatial_lon_max                                                    -4.2956
# time_coverage_start                                      2015-10-13T10:00:00Z
# time_coverage_end                                        2020-03-09T11:00:00Z
# institution                 Atlantic Oceanographic and Meteorological Labo...
# date_update                                              2020-04-06T00:34:57Z
# data_mode                                                                   R
# parameters                                                     DEPH TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_DB_4100668.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4100668
# wmo_platform_code                                                     4100668
# institution_edmo_code                                                    1799
# last_latitude_observation                                             25.2974
# last_longitude_observation                                           -78.1124
# last_date_observation                                    2020-03-01T08:00:00Z
#
#                                                                          4028  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    22.1544
# geospatial_lat_max                                                    40.2924
# geospatial_lon_min                                                    123.834
# geospatial_lon_max                                                   -155.217
# time_coverage_start                                      2018-06-17T19:04:00Z
# time_coverage_end                                        2021-05-31T23:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-06-07T02:52:07Z
# data_mode                                                                   R
# parameters                                                     DEPH TEMP PSAL
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_DB_5300623.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         5300623
# wmo_platform_code                                                     5300623
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             34.3354
# last_longitude_observation                                           -154.943
# last_date_observation                                    2021-06-22T14:00:00Z
#
#                                                                          4033  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    13.9118
# geospatial_lat_max                                                    45.6984
# geospatial_lon_min                                                   -157.954
# geospatial_lon_max                                                    18.9468
# time_coverage_start                                      2018-10-03T20:00:00Z
# time_coverage_end                                        2020-07-17T11:59:00Z
# institution                                                         Saildrone
# date_update                                              2021-06-16T15:06:31Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL CNDC ATMP ATMS CHLT DRYT GSPD L...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_SD_5801955.nc
# file_type                                                                  TS
# data_type                                                                  SD
# platform_code                                                         5801955
# wmo_platform_code                                                     5801955
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             45.6931
# last_longitude_observation                                            13.7096
# last_date_observation                                    2020-07-17T11:59:00Z
#
#                                                                          4034  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     4.0855
# geospatial_lat_max                                                    60.2113
# geospatial_lon_min                                                     -80.12
# geospatial_lon_max                                                    30.2223
# time_coverage_start                                      2002-04-13T05:00:00Z
# time_coverage_end                                        2021-05-31T22:10:00Z
# institution                 IRD Institut de recherche pour le developpemen...
# date_update                                              2021-06-07T04:17:49Z
# data_mode                                                                   M
# parameters                  DEPH PSAL PSAL_ADJUSTED PSAL_ADJUSTED_ERROR CN...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_TS_TS_FNAV.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            FNAV
# wmo_platform_code                                                        FNAV
# institution_edmo_code                                                     440
# last_latitude_observation                                                51.9
# last_longitude_observation                                             4.2333
# last_date_observation                                    2021-06-21T21:55:00Z
#
#                                                                          4035  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                    4.84833
# geospatial_lat_max                                                     71.749
# geospatial_lon_min                                                     -80.12
# geospatial_lon_max                                                    30.2248
# time_coverage_start                                      2001-12-21T22:48:00Z
# time_coverage_end                                        2021-05-31T12:56:00Z
# institution                 IRD Institut de recherche pour le developpemen...
# date_update                                              2021-06-07T06:03:53Z
# data_mode                                                                   M
# parameters                  DEPH PSAL PSAL_ADJUSTED PSAL_ADJUSTED_ERROR CN...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_TS_TS_FNHO.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            FNHO
# wmo_platform_code                                                        FNHO
# institution_edmo_code                                                     440
# last_latitude_observation                                             43.3167
# last_longitude_observation                                               5.35
# last_date_observation                                    2021-06-18T13:55:00Z
#
#                                                                          4036
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     14.388
# geospatial_lat_max                                                    44.5485
# geospatial_lon_min                                                   -97.2063
# geospatial_lon_max                                                   -50.9151
# time_coverage_start                                      2009-11-12T18:28:28Z
# time_coverage_end                                        2021-05-30T23:56:40Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-07T09:29:07Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP PSAL CNDC SSJT
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                       GL_TS_TS_WTDL.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTDL
# wmo_platform_code                                                        WTDL
# institution_edmo_code                                                     NaN
# last_latitude_observation                                             29.4481
# last_longitude_observation                                           -80.3214
# last_date_observation                                    2021-06-11T23:55:42Z
#
# [23 rows x 1215 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset only contains the aimed parameter (targeted_parameter) just check the `parameters` row of the above output.
# </div>

# %% [markdown]
# #### 4.1.5. By platform code
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# Let's look for files produced by a certain platform.<br>`Please set a platform code` next `and run the cell`:

# %%
targeted_platform_code = '41056'

# %% [markdown]
# Run the next cell to obtain just the files reported by such platform:

# %%
condition = info['platform_code']==targeted_platform_code
subset = info[condition]
subset.transpose()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed platform (targeted_platform_code) just check the `platform_code` row of the above output.
# </div>

# %% [markdown]
# #### 4.1.6. By provider
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# Let's look for files produced by a certain provider.<br>`Please set` a provider `name`or `edmo_code` ([SeaDataNet](https://edmo.seadatanet.org/search)) and `run the cell`:

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# For this task we can either use the `institution` name or the `institution_edmo_code` ([SeaDataNet](https://edmo.seadatanet.org/search)), nevertheless if the chosen dataset does not have a `index_platform.txt` file you won't be able to look for providers using the 'institution_edmo_code' as this information comes form such file. In such case use solely the `institution`.
# </div>

# %%
key, targeted_provider = 'institution', 'WHOI'
#key, targeted_provider = 'institution_edmo_code', '3844'

# %% [markdown]
# Run the next cell to obtain just the files reported by such provider:

# %%
condition = (info[key].astype(str).str.strip().str.contains(targeted_provider, na=False, case=False)) | (info[key] == targeted_provider)
subset = info[condition]
subset.transpose()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed provider (targeted_provider) just check the `insitution_edmo_code` and the `institution` row of the above output.
# </div>

# %% [markdown]
# #### 4.1.7. By several criterias at once
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# Set the collection of interest, range of time and bounding box to find only the files that match:

# %%
targeted_collection = 'history'
targeted_data_type = 'MO'
targeted_file_type = 'TS'
targeted_parameter = 'TEMP'

# %% [markdown]
# Run the next cell to apply the above filters:

# %%
condition1 = info['file_name'].str.contains(targeted_collection)
condition2 = info['data_type'] == targeted_data_type
condition3 = info['file_type'] == targeted_file_type
condition4 = info['parameters'].str.contains(targeted_parameter)

subset = info[(condition1) & (condition2) & (condition3) & (condition4)]
subset.transpose()
# Out:
#                                                                          111   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.249
# geospatial_lat_max                                                     18.251
# geospatial_lon_min                                                    -64.763
# geospatial_lon_max                                                    -64.763
# time_coverage_start                                      2011-04-15T16:50:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-16T18:07:38Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP DRYT GSPD VHM0 VMDR VTPK WDIR WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_41052.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           41052
# wmo_platform_code                                                       41052
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.251
# last_longitude_observation                                            -64.763
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          192   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.474
# geospatial_lat_max                                                     18.476
# geospatial_lon_min                                                    -66.099
# geospatial_lon_max                                                    -66.099
# time_coverage_start                                      2010-07-26T14:10:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-16T18:07:43Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP DRYT GSPD VHM0 VMDR VTPK WDIR WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_41053.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           41053
# wmo_platform_code                                                       41053
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.476
# last_longitude_observation                                            -66.099
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          281   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.259
# geospatial_lat_max                                                     18.261
# geospatial_lon_min                                                    -65.464
# geospatial_lon_max                                                    -65.457
# time_coverage_start                                      2013-10-01T00:00:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-16T17:47:20Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP DRYT GSPD VHM0 VMDR VTPK WDIR WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_41056.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           41056
# wmo_platform_code                                                       41056
# institution_edmo_code                                                     NaN
# last_latitude_observation                                               18.26
# last_longitude_observation                                            -65.458
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          368   \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                      17.86
# geospatial_lat_max                                                     17.869
# geospatial_lon_min                                                    -66.532
# geospatial_lon_max                                                    -66.524
# time_coverage_start                                      2009-08-01T00:00:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                 National Data Buoy Center (NDBC) National Ocea...
# date_update                                              2021-06-16T18:08:02Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP DRYT GSPD VHM0 VMDR VTPK WDIR WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_42085.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           42085
# wmo_platform_code                                                       42085
# institution_edmo_code                                                    1463
# last_latitude_observation                                               17.86
# last_longitude_observation                                            -66.524
# last_date_observation                                    2021-06-22T11:00:00Z
#
#                                                                          1812  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     14.532
# geospatial_lat_max                                                     14.928
# geospatial_lon_min                                                    -61.154
# geospatial_lon_max                                                    -60.952
# time_coverage_start                                      2004-10-23T00:40:00Z
# time_coverage_end                                        2021-05-31T23:46:00Z
# institution                 CEREMA Centre Etudes et Expertise sur les Risq...
# date_update                                              2021-06-16T17:56:50Z
# data_mode                                                                   R
# parameters                  DEPH TEMP VAVH VAVT VEPK VGHS VGTA VHM0 VPED V...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_MO_4100097.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         4100097
# wmo_platform_code                                                     4100097
# institution_edmo_code                                                    4533
# last_latitude_observation                                             14.5481
# last_longitude_observation                                           -61.0969
# last_date_observation                                    2021-06-22T14:30:00Z
#
#                                                                          1910  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     14.507
# geospatial_lat_max                                                     14.921
# geospatial_lon_min                                                    -61.176
# geospatial_lon_max                                                    -61.059
# time_coverage_start                                      2004-10-23T00:40:00Z
# time_coverage_end                                        2021-05-31T23:41:00Z
# institution                 CEREMA Centre Etudes et Expertise sur les Risq...
# date_update                                              2021-06-16T18:02:09Z
# data_mode                                                                   R
# parameters                  DEPH TEMP VAVH VAVT VEPK VGHS VGTA VHM0 VPED V...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_MO_4100098.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         4100098
# wmo_platform_code                                                     4100098
# institution_edmo_code                                                    4533
# last_latitude_observation                                             14.8903
# last_longitude_observation                                           -61.1144
# last_date_observation                                    2021-06-22T13:30:00Z
#
#                                                                          1960  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                      15.82
# geospatial_lat_max                                                      15.88
# geospatial_lon_min                                                      -57.5
# geospatial_lon_max                                                     -57.43
# time_coverage_start                                      2016-05-20T00:00:00Z
# time_coverage_end                                        2021-05-31T23:00:00Z
# institution                 Meteo-France / Centre de Météorologie Marine (...
# date_update                                              2021-06-16T17:42:59Z
# data_mode                                                                   R
# parameters                                 DEPH TEMP ATMS DRYT VGHS WDIR WSPD
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_MO_4100300.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         4100300
# wmo_platform_code                                                     4100300
# institution_edmo_code                                                    1190
# last_latitude_observation                                               15.84
# last_longitude_observation                                             -57.49
# last_date_observation                                    2021-06-22T15:00:00Z
#
#                                                                          2057  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     20.989
# geospatial_lat_max                                                     21.132
# geospatial_lon_min                                                    -65.014
# geospatial_lon_max                                                     -64.79
# time_coverage_start                                      2007-04-11T16:00:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                 National Data Buoy Center (NDBC) National Ocea...
# date_update                                              2021-06-16T17:57:32Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP DEWT DRYT GSPD VHM0 VMDR VTM02 ...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_41043.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           41043
# wmo_platform_code                                                       41043
# institution_edmo_code                                                    1463
# last_latitude_observation                                              21.061
# last_longitude_observation                                            -64.966
# last_date_observation                                    2021-06-22T11:40:00Z
#
#                                                                          2154  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     21.562
# geospatial_lat_max                                                     21.652
# geospatial_lon_min                                                    -58.695
# geospatial_lon_max                                                    -58.614
# time_coverage_start                                      2009-05-12T03:50:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                 National Data Buoy Center (NDBC) National Ocea...
# date_update                                              2021-06-16T17:52:16Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP DEWT DRYT GSPD VHM0 VMDR VTM02 ...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_41044.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           41044
# wmo_platform_code                                                       41044
# institution_edmo_code                                                    1463
# last_latitude_observation                                              21.639
# last_longitude_observation                                            -58.614
# last_date_observation                                    2021-06-22T11:40:00Z
#
#                                                                          2252  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     23.822
# geospatial_lat_max                                                     23.888
# geospatial_lon_min                                                     -70.87
# geospatial_lon_max                                                    -68.333
# time_coverage_start                                      2007-09-22T07:00:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                 National Data Buoy Center (NDBC) National Ocea...
# date_update                                              2021-06-16T17:41:53Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP DEWT DRYT GSPD VHM0 VMDR VTM02 ...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_41046.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           41046
# wmo_platform_code                                                       41046
# institution_edmo_code                                                    1463
# last_latitude_observation                                              23.838
# last_longitude_observation                                            -68.333
# last_date_observation                                    2021-06-22T11:40:00Z
#
#                                                                          2302  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     18.376
# geospatial_lat_max                                                     18.379
# geospatial_lon_min                                                     -67.28
# geospatial_lon_max                                                     -67.28
# time_coverage_start                                      2011-06-01T00:05:00Z
# time_coverage_end                                        2021-05-31T23:56:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-06-16T17:33:07Z
# data_mode                                                                   M
# parameters                                     DEPH TEMP VHM0 VMDR VTM02 VTPK
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_41115.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           41115
# wmo_platform_code                                                       41115
# institution_edmo_code                                                     NaN
# last_latitude_observation                                              18.379
# last_longitude_observation                                             -67.28
# last_date_observation                                    2021-06-22T11:26:00Z
#
#                                                                          2374  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     14.775
# geospatial_lat_max                                                     15.093
# geospatial_lon_min                                                    -75.064
# geospatial_lon_max                                                    -74.548
# time_coverage_start                                      2005-09-01T00:00:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                 National Data Buoy Center (NDBC) National Ocea...
# date_update                                              2021-06-16T18:03:10Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP ATMS DEWT DRYT GSPD VHM0 VMDR V...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_42058.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           42058
# wmo_platform_code                                                       42058
# institution_edmo_code                                                    1463
# last_latitude_observation                                              14.923
# last_longitude_observation                                            -74.918
# last_date_observation                                    2021-06-22T11:40:00Z
#
#                                                                          2458  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     15.006
# geospatial_lat_max                                                     15.252
# geospatial_lon_min                                                    -67.563
# geospatial_lon_max                                                    -67.472
# time_coverage_start                                      2007-04-17T23:00:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                 National Data Buoy Center (NDBC) National Ocea...
# date_update                                              2021-06-16T17:52:15Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP DEWT DRYT GSPD VHM0 VMDR VTM02 ...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_42059.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           42059
# wmo_platform_code                                                       42059
# institution_edmo_code                                                    1463
# last_latitude_observation                                              15.054
# last_longitude_observation                                            -67.472
# last_date_observation                                    2021-06-22T11:40:00Z
#
#                                                                          2550  \
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     16.332
# geospatial_lat_max                                                     16.433
# geospatial_lon_min                                                      -63.5
# geospatial_lon_max                                                    -63.188
# time_coverage_start                                      2009-04-28T02:50:00Z
# time_coverage_end                                        2021-05-31T23:50:00Z
# institution                 National Data Buoy Center (NDBC) National Ocea...
# date_update                                              2021-06-16T17:36:13Z
# data_mode                                                                   M
# parameters                  DEPH TEMP ATMP DEWT DRYT GSPD VHM0 VMDR VTM02 ...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                      GL_TS_MO_42060.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           42060
# wmo_platform_code                                                       42060
# institution_edmo_code                                                    1463
# last_latitude_observation                                              16.433
# last_longitude_observation                                            -63.331
# last_date_observation                                    2021-06-22T11:40:00Z
#
#                                                                          3722
# # product_id                                                    COP-GLOBAL-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_GLO_NRT_OBSE...
# geospatial_lat_min                                                     14.055
# geospatial_lat_max                                                     15.177
# geospatial_lon_min                                                    -62.312
# geospatial_lon_max                                                    -60.857
# time_coverage_start                                      2005-02-26T01:54:00Z
# time_coverage_end                                        2020-02-21T12:00:00Z
# institution                 CEREMA Centre Etudes et Expertise sur les Risq...
# date_update                                              2021-06-16T17:55:29Z
# data_mode                                                                   R
# parameters                  DEPH TEMP VAVH VAVT VEPK VGHS VGTA VHM0 VPED V...
# timeOverlap                                                              True
# spatialOverlap                                                           True
# netcdf                                                    GL_TS_MO_4100099.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         4100099
# wmo_platform_code                                                     4100099
# institution_edmo_code                                                    4533
# last_latitude_observation                                             14.1761
# last_longitude_observation                                           -60.9344
# last_date_observation                                    2020-02-21T12:00:00Z

# %% [markdown]
# ### 4.2. Exporting
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# If you just want to export the above table containing ftp link to download each file in subset and some more metadata as csv for sharing it (a lot more compact than sharing the actual files), just run the `next cells`:

# %%
subsetName = 'subsetOffiles.csv'
output_dir = os.getcwd()# Defaults to the current working directory; change it as you please

# %%
path2csv = os.path.join(output_dir,subsetName)
path2csv
# Out:
# '/DATA/shared_trainers/training-AMERICA/05 Jupyter Notebook - In Situ Observation Products/subsetOffiles.csv'

# %%
subset.to_csv(path2csv)

# %% [markdown]
# ### 4.3. Downloading
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# After you have created your own subset (see above examples about how-to), we will loop over the files in such subset and download each of them from the FTP server thanks to the `file_name` column, field that contains the ftp link to the file.

# %% [markdown]
# - Set the output directory.<br>By default: the current working directory.`Run the next cell`:

# %%
output_dir = os.getcwd()
output_dir
# Out:
# '/DATA/shared_trainers/training-AMERICA/05 Jupyter Notebook - In Situ Observation Products'

# %% [markdown]
# - Set the subset of files you aim to download. <br>This can be path to the CSV file created in 4.2 or the any subset created in 4.1.`Run the next cell`:

# %%
input_data = path2csv
#input_data = subset

# %% [markdown]
# - Download. <br>By default the download is limit to 5 platforms. Set a different treshold if you want.`Run the next cell`:

# %%
insitu.downloadFilesFromCSV(usr, pas, input_data, output_dir, 5)
# Out:
# ...Downloading files from platform : 41043
# ...........GL_TS_MO_41043.nc
# ...Downloading files from platform : 41044
# ...........GL_TS_MO_41044.nc
# ...Downloading files from platform : 41046
# ...........GL_TS_MO_41046.nc
# ...Downloading files from platform : 41052
# ...........GL_TS_MO_41052.nc
# ...Downloading files from platform : 41053
# ...........GL_TS_MO_41053.nc
# Ready!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the files have been donwloaded just check if you find them in the directory specified as <i>output directory</i>.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# FTP download might be forbidden in the remote server for security reasons. <br>If you experience an error please run this jupyter notebook locally for being able to actually download the files. Steps:
#     <ul>
#     <li>1. [Install anaconda](https://www.anaconda.com/distribution/): according to your OS (Windows,Linux,Mac...)</li>
#     <li>2. Navigate to the folder containing the notebooks (.ipynb files)</li>
#     <li>3. Run the following command at the Terminal (Mac/Linux) or Command Prompt (Windows): `jupyter notebook`</li>
#     </ul>
# </div>

# %% [markdown]
# ---
#
# # 5. Wrap-up
# [Go back to the "Table of Contents"](#Table-of-Contents)
#
# So far you should already know how to subset the product/dataset by several subsetting criterias as well as exporting and downloading the resulting subset of files.
