# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)

# %% [markdown]
# # COPERNICUS MARINE PHYSICAL SOUTH AMERICA TRAINING
#
# <div style="text-align: right"><i> 01-01-PHY </i></div>
#
# ***
#
# <center><h1>How to visualize maps of Temperature, Salinity, Mixed Layer Depth (MLD) and vector currents, to compute the density and plot vertical sections along a transect</h1></center>

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Run" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# # Table of contents
# - [1. Introduction](#1.-Introduction)
# - [2. Exercise n.1: Plot of maps](#2.-Exercise-n.1:-Plot-of-maps)
#     - [2.1. About the data](#2.1.-About-the-data)
#         - [2.1.1. Model description](#2.1.1.-Model-description)
#         - [2.1.2. Get more info on the product](#2.1.2.-Get-more-info-on-the-product)
#     - [2.2. Download the data](#2.2.-Download-the-data)
#         - [2.2.1. Parameters used for downloading the data](#2.2.1.-Parameters-used-for-downloading-the-data)
#         - [2.2.2. How to download the products?](#2.2.2.-How-to-download-the-products?)
#     - [2.3. The exercise](#2.3.-The-exercise)
#         - [2.3.1. Required modules](#2.3.1.-Required-modules)
#         - [2.3.2. Required Python version](#2.3.2.-Required-Python-version)
#         - [2.3.3. Import the modules](#2.3.3.-Import-the-modules)
#         - [2.3.4. Access the data](#2.3.4.-Access-the-data)
#         - [2.3.5. Set the configuration](#2.3.5.-Set-the-configuration)
#         - [2.3.6. Configure the variables for the plots](#2.3.6.-Configure-the-variables-for-the-plots)
#         - [2.3.7. Generate the maps](#2.3.7.-Generate-the-maps)
#         - [2.3.8. Generate the map of currents (vector)](#2.3.8.-Generate-the-map-of-currents-(vector))
# - [3. Exercise n.2: Plot of transects](#3.-Exercise-n.2:-Plot-of-transects)
#     - [3.1. About the data](#3.1.-About-the-data)
#     - [3.2. Download the data](#3.2.-Download-the-data)
#     - [3.3. The exercise](#3.3.-The-exercise)
#         - [3.3.1. Set the configuration](#3.3.1.-Set-the-configuration)
#         - [3.3.2. Configure the variables for the plot](#3.3.2.-Configure-the-variables-for-the-plot)
#         - [3.3.3. Function for plotting the transect](#3.3.3.-Function-for-plotting-the-transect)
#         - [3.3.4. Density and MLD comparison](#3.3.4.-Density-and-MLD-comparison)
# - [4. Conclusion](#4.-Conclusion)
# ***

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# The objective of this exercise is to use the CMEMS GLO-MFC model products to visualize the main physical fields in the Malvinas area.
#
# In particular, you will display:
#
# - horizontal maps of the different 2D and 3D variables, the latter also at different depths for two different months (January 2011 and August 2011)
# - vertical sections of temperature, salinity and density along a transect in the Malvinas area highlighting the vertical structure of these fields in two different seasons.

# %% [markdown]
# ***

# %% [markdown]
# # 2. Exercise n.1: Plot of maps

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# # 2.1. About the data

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# ### 2.1.1. Model description
# [Go back to the "Table of contents"](#Table-of-contents)
#
# This example is based on the product whose Identifier is:

# %% [markdown]
# ### [GLOBAL_REANALYSIS_PHY_001_030](https://resources.marine.copernicus.eu/?option=com_csw&view=details&product_id=GLOBAL_REANALYSIS_PHY_001_030)

# %% [markdown]
# The GLORYS12V1 product is the CMEMS global ocean eddy-resolving (1/12° horizontal resolution, 50 vertical levels) reanalysis covering the altimetry (1993 onward).
#
# It is based largely on the current real-time global forecasting CMEMS system. The model component is the NEMO platform driven at surface by ECMWF ERA-Interim then ERA5 reanalyses for recent years. Observations are assimilated by means of a reduced-order Kalman filter. Along track altimeter data (Sea Level Anomaly), Satellite Sea Surface Temperature, Sea Ice Concentration and In situ Temperature and Salinity vertical Profiles are jointly assimilated. Moreover, a 3D-VAR scheme provides a correction for the slowly-evolving large-scale biases in temperature and salinity.
#
# This product includes daily and monthly mean files for temperature, salinity, currents, sea level, mixed layer depth and ice parameters from the top to the bottom. The global ocean output files are displayed on a standard regular grid at 1/12° (approximatively 8 km) and on 50 standard levels.

# %% [markdown]
# <img src="./img/GLOBAL_REANALYSIS_PHY_001_030_table1.png">

# %% [markdown]
# ### 2.1.2. Get more info on the product
# [Go back to the "Table of contents"](#Table-of-contents)
#
# 1. You can find info on this product and access to the download services in the [dedicated Product Page on Copernicus Marine (CMEMS) Web portal](https://resources.marine.copernicus.eu/?option=com_csw&view=details&product_id=GLOBAL_REANALYSIS_PHY_001_030)
# <br><br>
# 2. For **detailed information** about the product, please consult the **document**: [Product User Manual (PUM)](./docs/CMEMS-GLO-PUM-001-030.pdf)
# <br><br>
# 3. For information about **the quality and validation** of the product, please consult the **document**: [Quality Information Document (QUID)](./docs/CMEMS-GLO-QUID-001-030.pdf)

# %% [markdown]
# ***

# %% [markdown]
# # 2.2. Download the data

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# ### 2.2.1. Parameters used for downloading the data
# [Go back to the "Table of contents"](#Table-of-contents)
#
#
# | Parameter | Value |
# | :---: | :---|
# | **Product** | GLOBAL_REANALYSIS_PHY_001_030 |
# | **Dataset** | global-reanalysis-phy-001-030-monthly |
# | **variables** | <ul><li>thetao</li><li>mlost</li><li>so</li><li>uo</li><li>vo</li></ul> |
# | **Frequency** | monthly |
# | **Lat min** | -56 |
# | **Lat max** | -36 |
# | **Lon min** | -65 |
# | **Lon max** | -42 |
# | **Timesteps** | 2011-01, 2011-08, 2015-04, 2015-05 |
# | **Depths** | from 0 to 2000 |
# | **Service for downloading** | SUBSETTER |
# | **Files total dimension** | 100MB |

# %% [markdown]
# ### 2.2.2. How to download the products?
#
# [Go back to the "Table of contents"](#Table-of-contents)
#
# If you need some help about the different services for downloading the CMEMS products, please check this [tutorial](
# https://help-cmems.mercator-ocean.fr/en/articles/4469993-how-to-download-copernicus-marine-data)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Get the CMEMS User credentials</b>
# <hr>
# The data are already available in this notebook. But if you want to download the data by yourself, please be sure to have by your CMEMS User credentials. Otherwise please get them <a href="http://marine.copernicus.eu/services-portfolio/register-now/" target="_blank">here</a>.

# %% [markdown]
# ### Download with *motuclient*
#
# Data can be alternatively downloaded with **motuclient**, a multiplatform python script to automate extraction of information from the Marine Copernicus portal. To install motuclient:

# %% [markdown]
# ```
# !pip install motuclient
# ```

# %%
# !pip install motuclient

# %% [markdown]
# To get more info on motuclient visit the related [web page](https://help-cmems.mercator-ocean.fr/en/articles/4796533-what-are-the-motu-client-motuclient-and-python-requirements).

# %% [markdown]
# Using *motuclient* you'll be able to download data with the following command line. You have to copy this line to another cell for being execute (**NOTE:** don't forget to set username and password!):

# %% [markdown]
# *Consider that there is a different command line for each file that will be downloaded.*

# %% [markdown]
# ```
# !python -m motuclient --motu https://my.cmems-du.eu/motu-web/Motu --service-id GLOBAL_REANALYSIS_PHY_001_030-TDS --product-id global-reanalysis-phy-001-030-monthly --longitude-min -65 --longitude-max -42 --latitude-min -56 --latitude-max -36 --date-min "2011-01-16 12:00:00" --date-max "2011-01-16 12:00:00" --depth-min 0 --depth-max 2000 --variable mlotst --variable thetao --variable uo --variable vo --variable so --out-dir data --out-name global-reanalysis-phy-001-030-monthly_2011-01.nc --user <USERNAME> --pwd "<PASSWORD>"
# ```

# %% [markdown]
# ```
# !python -m motuclient --motu https://my.cmems-du.eu/motu-web/Motu --service-id GLOBAL_REANALYSIS_PHY_001_030-TDS --product-id global-reanalysis-phy-001-030-monthly --longitude-min -65 --longitude-max -42 --latitude-min -56 --latitude-max -36 --date-min "2011-08-16 12:00:00" --date-max "2011-08-16 12:00:00" --depth-min 0 --depth-max 2000 --variable mlotst --variable thetao --variable uo --variable vo --variable so --out-dir data --out-name global-reanalysis-phy-001-030-monthly_2011-08.nc --user <USERNAME> --pwd "<PASSWORD>"
# ```

# %% [markdown]
# ```
# !python -m motuclient --motu https://my.cmems-du.eu/motu-web/Motu --service-id GLOBAL_REANALYSIS_PHY_001_030-TDS --product-id global-reanalysis-phy-001-030-monthly --longitude-min -65 --longitude-max -42 --latitude-min -56 --latitude-max -36 --date-min "2015-04-16 00:00:00" --date-max "2015-04-16 00:00:00" --depth-min 0 --depth-max 2000 --variable mlotst --variable thetao --variable uo --variable vo --variable so --out-dir data --out-name global-reanalysis-phy-001-030-monthly_2015-04.nc --user <USERNAME> --pwd "<PASSWORD>"
# ```

# %% [markdown]
# ```
# !python -m motuclient --motu https://my.cmems-du.eu/motu-web/Motu --service-id GLOBAL_REANALYSIS_PHY_001_030-TDS --product-id global-reanalysis-phy-001-030-monthly --longitude-min -65 --longitude-max -42 --latitude-min -56 --latitude-max -36 --date-min "2015-05-16 12:00:00" --date-max "2015-05-16 12:00:00" --depth-min 0 --depth-max 2000 --variable mlotst --variable thetao --variable uo --variable vo --variable so --out-dir data --out-name global-reanalysis-phy-001-030-monthly_2015-05.nc --user <USERNAME> --pwd "<PASSWORD>"
# ```

# %% [markdown]
# Check if the file has been created...

# %%
import os
for filename in os.listdir('data'):
    if filename.endswith(".nc"):
        print(filename)
# Out:
# global-reanalysis-phy-001-030-monthly_2011-01.nc
# global-reanalysis-phy-001-030-monthly_2011-08.nc
# global-reanalysis-phy-001-030-monthly_2015-04.nc
# global-reanalysis-phy-001-030-monthly_2015-05.nc

# %% [markdown]
# ***

# %% [markdown]
# # 2.3. The exercise

# %% [markdown]
# ### 2.3.1. Required modules

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# | Module name | Description |
# | :---: | :---|
# | **os** | [ Miscellaneous operating system interfaces](https://docs.python.org/3.7/library/os.html) for managing paths, creating directories,... |
# | **numpy** | [NumPy](https://numpy.org/) is the fundamental package for scientific computing with Python and for managing ND-arrays |
# | **xarray** | [Xarray](http://xarray.pydata.org/en/stable/) introduces labels in the form of dimensions, coordinates and attributes on top of raw NumPy-like arrays, which allows for a more intuitive, more concise, and less error-prone developer experience. |
# | **matplotlib** |[Matplotlib](https://matplotlib.org/) is a Python 2D plotting library which produces publication quality figures |
# | **basemap** |[The matplotlib basemap toolkit](https://matplotlib.org/basemap/) is a library for plotting 2D data on maps in Python. |
# | **gsw** |[Gibbs-SeaWater (GSW) Oceanographic Toolbox](http://www.teos-10.org/software.htm) contains the TEOS-10 subroutines for evaluating the thermodynamic prope.

# %% [markdown]
# The most important module used in this example is **gsw** (Gibbs-SeaWater).
#
# The [Gibbs-SeaWater (GSW) Oceanographic Toolbox](http://www.teos-10.org/software.htm) contains the TEOS-10 subroutines for evaluating the thermodynamic properties of pure water (using IAPWS-09) and seawater (using IAPWS-08 for the saline part). The GSW library does not provide properties of ice or moist air (these properties can be found in the SIA library). This GSW Oceanographic Toolbox does not adhere to strict basic-SI units but rather oceanographic units are adopted.
#
# This Python implementation of the Thermodynamic Equation of Seawater 2010 (TEOS-10) is based primarily on numpy ufunc wrappers of the GSW-C implementation. We expect it to replace the original python-gsw pure-python implementation after a brief overlap period. The primary reasons for this change are that by building on the C implementation we reduce code duplication and we gain an immediate update to the 75-term equation. Additional benefits include a major increase in speed, a reduction in memory usage, and the inclusion of more functions. The penalty is that a C (or MSVC C++ for Windows) compiler is required to build the package from source.
#
# **References**:
#
# - [gsw python GitHub](https://github.com/TEOS-10/GSW-Python)
#
# - [Documentation on GSW-Python](https://teos-10.github.io/GSW-Python)
#
# - [Documentation on gsw.density](https://teos-10.github.io/GSW-Python/density.html)

# %% [markdown]
# ### 2.3.2. Required Python version
# [Go back to the "Table of contents"](#Table-of-contents)
#
# Install the needed Python modules (for local installation, can be skipped during Training)

# %% [markdown]
# **Requirement: Python version 3.7**

# %% [markdown]
# Check your Python version:

# %%
# !python --version

# %% [markdown]
# If needed you can install the right Python version in this way:
# ```
# conda install python=3.7.10
# ```

# %% [markdown]
# If you are using the standard *Anaconda3* installation, you can install the needed modules executing the following command in the following cell:
# ```
# conda install numpy=1.19.2 numpy-base=1.19.2 xarray=0.17.0 matplotlib=3.2.2 matplotlib-base=3.2.2 basemap=1.2.0 basemap-data-hires=1.2.0 netcdf4=1.5.6 basemap-data-hires=1.2.0 geos=3.6.2 proj4=5.2.0 pyproj=1.9.6 pyshp=2.1.3
# ```

# %% [markdown]
# And now install the **gsw** package which belongs to the channel **conda-forge**:
# ```
# conda install -c conda-forge gsw
# ```

# %% [markdown]
# ### 2.3.3. Import the modules
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# For avoiding the warning messages during the execution and installation process, at first remove them:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
import gsw.density as density

# %% [markdown]
# *Don't change the following constants, which define the training and the notebook codes*:

# %%
REGION_CODE = "01"
NB_CODE = "01"

# %% [markdown]
# **checkDir**: function for creating a path, if needed

# %%
def checkDir(outPath):
    if not os.path.exists(outPath):
        os.makedirs(outPath)

# %% [markdown]
# **getRangeIndexes**: function for getting the indexes of the array *arr* between the *var_min* and *var_max* values:

# %%
def getRangeIndexes(arr, var_min, var_max):
    return np.where((arr >= var_min) & (arr <= var_max))[0]

# %% [markdown]
# Set the paths:

# %%
# Path for netcdf files
data_path = './data'
# Path for the output files (images, etc)
out_path = './out/'+REGION_CODE+'-'+NB_CODE

# %%
# Create directories
checkDir(data_path)
checkDir(out_path)

# %% [markdown]
# Check if the new directories have been created...

# %%
for filename in os.listdir('.'):
    print(filename)
# Out:
# data
# docs
# img
# .ipynb_checkpoints
# out
# 01-01-PHY-maps-computedensity-verticalsection-transect.ipynb

# %% [markdown]
# ... and if the data files are available:

# %%
for filename in os.listdir(data_path):
    print(filename)
# Out:
# .keep
# global-reanalysis-phy-001-030-monthly_2011-01.nc
# global-reanalysis-phy-001-030-monthly_2011-08.nc
# global-reanalysis-phy-001-030-monthly_2015-04.nc
# global-reanalysis-phy-001-030-monthly_2015-05.nc
# .ipynb_checkpoints

# %% [markdown]
# ### 2.3.4. Access the data
# [Go back to the "Table of contents"](#Table-of-contents)

# %%
# Input netcdf files
file_f = { "2011-01": "global-reanalysis-phy-001-030-monthly_2011-01.nc", 
           "2011-08": "global-reanalysis-phy-001-030-monthly_2011-08.nc",
           "2015-04": "global-reanalysis-phy-001-030-monthly_2015-04.nc", 
           "2015-05": "global-reanalysis-phy-001-030-monthly_2015-05.nc" }

# %%
# Open the nc datasets
file_ds = { k:  xr.open_dataset(os.path.join(data_path, v)) for k,v in file_f.items()}

# %% [markdown]
# Set the array index for accessing the desired dataset in the datasets arrays:

# %%
# index for the ds array
j = "2011-01"
#j = "2011-08"
#j = "2015-04"
#j = "2015-05"

# %% [markdown]
# ### Get info about the dataset :

# %%
file_ds[j].info
# Out:
# <bound method Dataset.info of <xarray.Dataset>
# Dimensions:    (depth: 40, latitude: 241, longitude: 277, time: 1)
# Coordinates:
#   * depth      (depth) float32 0.494 1.541 2.646 ... 1.684e+03 1.942e+03
#   * latitude   (latitude) float32 -56.0 -55.92 -55.83 ... -36.17 -36.08 -36.0
#   * time       (time) datetime64[ns] 2011-01-16T12:00:00
#   * longitude  (longitude) float32 -65.0 -64.92 -64.83 ... -42.17 -42.08 -42.0
# Data variables:
#     mlotst     (time, latitude, longitude) float32 ...
#     vo         (time, depth, latitude, longitude) float32 ...
#     thetao     (time, depth, latitude, longitude) float32 ...
#     uo         (time, depth, latitude, longitude) float32 ...
#     so         (time, depth, latitude, longitude) float32 ...
# Attributes: (12/17)
#     title:                         Monthly mean fields for product GLOBAL_REA...
#     references:                    http://marine.copernicus.eu
#     credit:                        E.U. Copernicus Marine Service Information...
#     licence:                       http://marine.copernicus.eu/services-portf...
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     producer:                      CMEMS - Global Monitoring and Forecasting ...
#     ...                            ...
#     source:                        MERCATOR GLORYS12V1
#     product_user_manual:           http://marine.copernicus.eu/documents/PUM/...
#     quality_information_document:  http://marine.copernicus.eu/documents/QUID...
#     _CoordSysBuilder:              ucar.nc2.dataset.conv.CF1Convention
#     comment:
#     history:                       Data extracted from dataset http://localho...>

# %% [markdown]
# About the variables:

# %%
file_ds[j].data_vars

# %% [markdown]
# Coordinates:

# %%
file_ds[j].coords

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **The dataset is 3D! You have depth levels!**
#
# The xarray dataset ***file_ds*** is extracted from a **3D dataset**

# %% [markdown]
# Try to check the depth levels. Type ```file_ds[j].depth``` in the cell below and execute it:

# %%
file_ds[j].depth

# %% [markdown]
# #### Let consider the variables' names:

# %%
variables = ["thetao","so","mlotst","uo","vo"]

for v in variables:
    print(" * " + v + " is " + file_ds[j][v].long_name)

# %% [markdown]
# #### Get info about the "Temperature" 3D field :

# %% [markdown]
# To get info about Temperature:

# %%
file_ds[j].data_vars['thetao']
# Out:
# <xarray.DataArray 'thetao' (time: 1, depth: 40, latitude: 241, longitude: 277)>
# [2670280 values with dtype=float32]
# Coordinates:
#   * depth      (depth) float32 0.494 1.541 2.646 ... 1.684e+03 1.942e+03
#   * latitude   (latitude) float32 -56.0 -55.92 -55.83 ... -36.17 -36.08 -36.0
#   * time       (time) datetime64[ns] 2011-01-16T12:00:00
#   * longitude  (longitude) float32 -65.0 -64.92 -64.83 ... -42.17 -42.08 -42.0
# Attributes:
#     long_name:      Temperature
#     standard_name:  sea_water_potential_temperature
#     units:          degrees_C
#     unit_long:      Degrees Celsius
#     cell_methods:   area: mean
#     _ChunkSizes:    [  1   7 341 720]

# %% [markdown]
# #### Get info about the "Salinity" 3D field :

# %% [markdown]
# To get info about Salinity:

# %%
file_ds[j].data_vars['so']

# %% [markdown]
# #### Get info about  "Mixed layer Depth" 2D field :
#
# To get info about mixed-later-depth:

# %%
file_ds[j].data_vars['mlotst']

# %% [markdown]
# #### Get info about "Eastward Velocity" 3D field :
#
# To get info about sea water velocity:

# %%
file_ds[j].data_vars['uo']

# %% [markdown]
# #### Get info about  "Northward Velocity" 3D field :
#
# To get info about sea water velocity:

# %%
file_ds[j].data_vars['vo']

# %% [markdown]
# ### 2.3.5. Set the configuration
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# Let's check the coordinates names in the cells above (check the ***ds.coords*** outputs) and set the correct variables below:

# %%
# Set the coordinate names (used later for accessing the data)
lon_name = "longitude"
lat_name = "latitude"
time_name = "time"
depth_name = "depth"

# %% [markdown]
# Do the same for the variables names (check the ***ds.data_vars*** outputs):

# %%
# Set the variable names
tem_name = "thetao"
sal_name = "so"
mld_name = "mlotst"
uo_name = "uo"
vo_name = "vo"

# %% [markdown]
# ### 2.3.6. Configure the variables for the plots
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# #### Let's try to plot the map of the ensemble mean and error for Temperature at first

# %% [markdown]
# Set the variable to plot

# %%
# --- Choose the variable to plot (but comment the others with the symbol #): ---
#
var_sel_name = mld_name
#var_sel_name = tem_name
#var_sel_name = sal_name
#var_sel_name = uo_name
#var_sel_name = vo_name

# %%
file_ds.keys()
# Out:
# dict_keys(['2011-01', '2011-08', '2015-04', '2015-05'])

# %%
var_sel_1 = file_ds["2011-01"][var_sel_name]
var_sel_2 = file_ds["2011-08"][var_sel_name]

var_sel = var_sel_1

dataset_3D = False 
if depth_name in var_sel.coords:
    dataset_3D = True
    
# --- Set up the arrays of coordinates for the selected dataset ---
# 
lats = var_sel[lat_name]
lons = var_sel[lon_name]
times = var_sel[time_name]
depths = var_sel[depth_name] if dataset_3D else []

# %% [markdown]
# Set the limits for the area: choose the min and max values for the coordinates (and comment with the symbol # the unnecessary ones!):

# %%
# Set lat-lon limits - FULL AREA
lat_min = lats.min()
lat_max = lats.max()
lon_min = lons.min()
lon_max = lons.max()

# # Set lat-lon limits - CUSTOM AREA
# lon_min = -65
# lon_max = -42
# lat_min = -56
# lat_max = -36

# %% [markdown]
# Set the variable's min and max values for the plots and the colorbars (otherwise assign to *None* for authomatic colobar limits):

# %%
#colorbar_min_value, colorbar_max_value = None, None #authomatic colobar limits
colorbar_min_value, colorbar_max_value = 0, 400

# %% [markdown]
# Set the desired depth (in meters)

# %%
d = 0

# %% [markdown]
# ### 2.3.7. Generate the maps
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# #### Plot configuration

# %%
# Plot configuration
width_inch = 18
height_inch = 8

# Map configuration
map_config = { 
#     "projection": "merc",
    "llcrnrlat": lat_min,
    "llcrnrlon": lon_min,
    "urcrnrlat": lat_max,
    "urcrnrlon": lon_max,
    "resolution": 'i',
    "epsg": 4326
}

# Axes labels
fontsize = 14
xlabel = 'longitude [deg]'
ylabel = 'latitude [deg]'
xlabelpad = 30
ylabelpad = 40

# Colorbar configuration
cmap = "jet"
cbar_position = "right"

title_fontstyle = {
    "fontsize": "14",
    "fontstyle": "italic",
    "fontweight": "bold",
    "pad": 30
}

label_fontstyle = {
    "fontsize": "12",
    "labelpad": 30
}

# %% [markdown]
# #### Map generation

# %%
# Set the coordinates indexes
lat_indexes = getRangeIndexes(lats, lat_min, lat_max)
lon_indexes = getRangeIndexes(lons, lon_min, lon_max)
time_indexes = [0]
depth_indexes = [0]

# Get the selected coordinates:
lats_sel = lats[lat_indexes]
lons_sel = lons[lon_indexes]

fig = plt.figure(figsize=(width_inch, height_inch))

map = Basemap(**map_config)



### --- PLOT 1 ---###
fig.add_subplot(1, 2, 1)

var_sel = var_sel_1

if dataset_3D:
    var_sel = var_sel[0, :, lat_indexes, lon_indexes].sel(depth=d,method='nearest')
else: 
    var_sel = var_sel[0, lat_indexes, lon_indexes]

## contour fill
min_value = var_sel.min() if colorbar_min_value is None else colorbar_min_value
max_value = var_sel.max() if colorbar_max_value is None else colorbar_max_value
step_value = 0.5
contour_levels = np.arange(min_value, max_value, step_value)
#map.contourf(xx, yy, var_sel, contour_levels, cmap=cmap)

## pcolormesh
x = np.linspace(0, map.urcrnrx, var_sel.shape[1])
y = np.linspace(0, map.urcrnry, var_sel.shape[0])

xx, yy = np.meshgrid(lons_sel, lats_sel)

# colormesh = map.pcolormesh(xx, yy, data, cmap=cmap)
colormesh = map.pcolormesh(xx, yy, var_sel, vmin=min_value, vmax=max_value, cmap=cmap)

## draw meridians and parallels
step_lat = float((lat_max - lat_min) / 5)
step_lon = float((lon_max - lon_min) / 5)

parallels = np.arange(lat_min, lat_max, step_lat)
meridians = np.arange(lon_min, lon_max, step_lon) 

map.drawmeridians(meridians, labels=[0,0,0,1], fmt="%2.1f")
map.drawparallels(parallels, labels=[1,0,0,0], fmt="%2.1f")

## draw colorbar
map.colorbar(colormesh, cbar_position)

## draw countries...
map.drawcountries(linewidth=0.25, color='olive')
map.fillcontinents(color='lightgray',lake_color='aqua')

## ... or draw the world using data from different providers (comment the previous lines!)
#     map.arcgisimage(service='World_Shaded_Relief', xpixels = 1500, verbose=False)
#     map.arcgisimage(service='ESRI_Imagery_World_2D', xpixels = 1500, verbose=False) 
#     map.bluemarble()
#     map.etopo()
#     map.shadedrelief()

# set title
title_sel = var_sel.long_name
timestep = np.datetime_as_string(var_sel.time,'h')
var_str = "{} [{}]".format(title_sel, var_sel.units)
if dataset_3D:
    depth_str = "{:.2f}{}".format(float(var_sel[depth_name]), "[m]")
    title = ' - '.join((var_str, timestep, depth_str))
else:
    title = ' - '.join((var_str, timestep))

## draw title and axes labels
plt.title(title, **title_fontstyle)
plt.xlabel(xlabel, labelpad=xlabelpad, fontsize=12)
plt.ylabel(ylabel, labelpad=ylabelpad, fontsize=12)    



### --- PLOT 2 ---###
fig.add_subplot(1, 2, 2)

var_sel = var_sel_2

if dataset_3D:
    var_sel = var_sel[0, :, lat_indexes, lon_indexes].sel(depth=d,method='nearest')
else: 
    var_sel = var_sel[0, lat_indexes, lon_indexes]

## contour fill
min_value = var_sel.min() if colorbar_min_value is None else colorbar_min_value
max_value = var_sel.max() if colorbar_max_value is None else colorbar_max_value
step_value = 0.5
contour_levels = np.arange(min_value, max_value, step_value)
# map.contourf(xx, yy, data, contour_levels, cmap=cmap)

colormesh = map.pcolormesh(xx, yy, var_sel, vmin=min_value, vmax=max_value, cmap=cmap)

## draw meridians and parallels
step_lat = float((lat_max - lat_min) / 5)
step_lon = float((lon_max - lon_min) / 5)

parallels = np.arange(lat_min, lat_max, step_lat)
meridians = np.arange(lon_min, lon_max, step_lon) 

map.drawmeridians(meridians, labels=[0,0,0,1], fmt="%2.1f")
map.drawparallels(parallels, labels=[1,0,0,0], fmt="%2.1f")

## draw colorbar
map.colorbar(colormesh, cbar_position)

## draw countries...
map.drawcountries(linewidth=0.25, color='olive')
map.fillcontinents(color='lightgray',lake_color='aqua')

## ... or draw the world using data from different providers (comment the previous lines!)
#    map.arcgisimage(service='World_Shaded_Relief', xpixels = 1500, verbose=False)       
#    map.arcgisimage(service='ESRI_Imagery_World_2D', xpixels = 1500, verbose=False)
#    map.bluemarble()
#    map.etopo()
#    map.shadedrelief()

# set title
title_sel = var_sel.long_name
timestep = np.datetime_as_string(var_sel.time,'h')
var_str = "{} [{}]".format(title_sel, var_sel.units)
var_str = "{} [{}]".format(title_sel, var_sel.units)
if dataset_3D:
    depth_str = "{:.2f}{}".format(float(var_sel[depth_name]), "[m]")
    title = ' - '.join((var_str, timestep, depth_str))
else:
    title = ' - '.join((var_str, timestep))

## draw title and axes labels
plt.title(title, **title_fontstyle)
plt.xlabel(xlabel, labelpad=xlabelpad, fontsize=12)
plt.ylabel(ylabel, labelpad=ylabelpad, fontsize=12) 




# output file
output_file = os.path.join(out_path,title.replace(' ','_')) + ".png"

# save the output file
plt.savefig(output_file)

plt.show()

plt.close()

# %% [markdown]
# ### Analysis of the variability of the mixed layer depth in the area.
#
# Large uncertainties are usually found where there is an abrupt change in temperature (called thermocline) which is difficult to model accurately. Above the thermocline exists the so called "Mixed Layer" in which the water is well mixed, so all the properties of the water are homogeneous. The vertical extension of the Mixed Layer is shown by the variable Mixed Layer Depth (MLD) .
#
# Look at the change between the seasons in 2011, how can you explain the changes that you see near 40°S? And the changes near 50°S?

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### LET'S TRY: Change the plot!
#
# If you want, you can change the above plot.
#
# For example, you could:
# - change the variable to plot
# - change the area
# - change the min/max values for the choosen variable
# - change the depth level (only for 3D datasets! ;))
#
# Try to plot salinity at 100m and temperature at 100m
#
# Go back to [Configure the variables for the plots](#2.3.6.-Configure-the-variables-for-the-plots) and then re-execute the cell for generating the plot. Try!

# %% [markdown]
# ### 2.3.8. Generate the map of currents (vector)
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# Several studies of the Malvinas current were performed in that area using GLO MFC products.
#
# For 2015, with a focus on the 41°S area and the confluence with the Brasil current:
# ["Fronts of the Malvinas Current System: Surface and Subsurface Expressions Revealed by Satellite Altimetry, Argo Floats, and Mercator Operational Model Outputs"](https://doi.org/10.1029/2018JC013887)
#
# *A pdf version of this article can be found in docs/ and downloadable [here](./docs/2018JC013887.pdf)*
#
# For 2011, with a focus on the 51°S area and the water masses in the southern part of the domain:
# ["Revisiting the Malvinas Current Upper Circulation and Water Masses Using a High-Resolution Ocean Reanalysis"](https://agupubs.onlinelibrary.wiley.com/doi/10.1029/2021JC017271).
#
#
# Let's start by having a look at the surface currents in 2015

# %% [markdown]
# Set the index for the dataset array

# %%
# index for the dataset array
#j = "2011-01"
#j = "2011-08"
#j = "2015-04"
j = "2015-05"

# %% [markdown]
# Set the limits for the area: choose the min and max values for the coordinates (and comment with the symbol # the unnecessary ones!):

# %%
# Set lat-lon limits - FULL AREA
lat_min = lats.min()
lat_max = lats.max()
lon_min = lons.min()
lon_max = lons.max()

# # Set lat-lon limits - CUSTOM AREA
# lon_min = -65
# lon_max = -42
# lat_min = -56
# lat_max = -36

# %% [markdown]
# Set the desired depth (in meters)

# %%
d = 0

# %% [markdown]
# Set the variable's min and max values for the plot and the colorbar (otherwise assign None):

# %%
#min_value, max_value = -0.5, 2
min_value, max_value = None, None # set None, None for authomatic colobar limits

# %%
# Skip points for the vectors of directions
#skip_points = 15 # for wider areas
skip_points = 7 # for narrow areas

# %%
# Vector scale
v_scale = 18

# %%
# --- Choose the variable to plot
uo_sel = file_ds[j][uo_name]
vo_sel = file_ds[j][vo_name]
mod_sel = (uo_sel**2+vo_sel**2)**0.5 

var_sel = mod_sel

dataset_3D = False 
if depth_name in var_sel.coords:
    dataset_3D = True
    
# --- Set up the arrays of coordinates for the selected dataset ---
lats = var_sel[lat_name]
lons = var_sel[lon_name]
times = var_sel[time_name]
depths = var_sel[depth_name] if dataset_3D else []

# %%
for t in time_indexes:
    if dataset_3D:
        data = var_sel[t, :, lat_indexes, lon_indexes].sel(depth=d,method='nearest')
        data_uo = uo_sel[t, :, lat_indexes, lon_indexes].sel(depth=d,method='nearest')
        data_vo = vo_sel[t, :, lat_indexes, lon_indexes].sel(depth=d,method='nearest')
    else: 
        data = var_sel[t, lat_indexes, lon_indexes]
        data_uo = uo_sel[t, lat_indexes, lon_indexes]
        data_vo = vo_sel[t, lat_indexes, lon_indexes]

    plt.figure(figsize=(width_inch, height_inch))

    map = Basemap(**map_config)

    ## contour fill
    min_value = data.min() if min_value is None else min_value
    max_value = data.max() if max_value is None else max_value
    step_value = 0.5
    
    ## pcolormesh
    x = np.linspace(0, map.urcrnrx, data.shape[1])
    y = np.linspace(0, map.urcrnry, data.shape[0])
    
    xx, yy = np.meshgrid(lons_sel, lats_sel)
    
    colormesh = map.pcolormesh(xx, yy, data, vmin=min_value, vmax=max_value, cmap=cmap)
    
    ## --- plot directions ---        
    u = data_uo
    v = data_vo
    
    u_skip = u[::skip_points, ::skip_points]
    v_skip = v[::skip_points, ::skip_points]
    xx_skip = xx[::skip_points, ::skip_points]
    yy_skip = yy[::skip_points, ::skip_points]
    
    map.quiver(xx_skip, yy_skip, u_skip, v_skip, scale=v_scale)

    ## draw meridians and parallels
    step_lat = float((lat_max - lat_min) / 5)
    step_lon = float((lon_max - lon_min) / 5)

    parallels = np.arange(lat_min, lat_max, step_lat)
    meridians = np.arange(lon_min, lon_max, step_lon) 

    map.drawmeridians(meridians, labels=[0,0,0,1], fmt="%2.1f")
    map.drawparallels(parallels, labels=[1,0,0,0], fmt="%2.1f")

    ## draw colorbar
    map.colorbar(colormesh, cbar_position)

    ## draw countries...
    map.drawcountries(linewidth=0.25, color='olive')
    map.fillcontinents(color='lightgray',lake_color='aqua')

    ## ... or draw the world using data from different providers (comment the previous lines!)
#     map.arcgisimage(service='World_Shaded_Relief', xpixels = 1500, verbose=False)
#     map.arcgisimage(service='ESRI_Imagery_World_2D', xpixels = 1500, verbose=False) 
#     map.bluemarble()
#     map.etopo()
#     map.shadedrelief()

    # set title
    title_sel = "Currents Velocity"
    timestep = np.datetime_as_string(times[t],'h')
    var_str = "{} [{}]".format(title_sel, "m per s")
    if dataset_3D:
        depth_str = "{:.2f}{}".format(float(data[depth_name]), "[m]")
        title = ' - '.join((var_str, timestep, depth_str))
    else:
        title = ' - '.join((var_str, timestep))
    
    ## draw title and axes labels
    plt.title(title, **title_fontstyle)
    plt.xlabel(xlabel, labelpad=xlabelpad, fontsize=12)
    plt.ylabel(ylabel, labelpad=ylabelpad, fontsize=12)    
    
    # output file
    output_file = os.path.join(out_path,title.replace(' ','_')) + ".png"

    # save the output file
    plt.savefig(output_file)

    plt.show()

    plt.close()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### LET'S TRY: Change the plot!
#
# If you want, you can change the above plot.
#
# For example, you could:
# - change the time period
# - change the min/max values for the choosen variable
# - change the depth level (only for 3D datasets! ;))
#
# Go back to [Configure the variables for the plots](#2.3.8.-Configuration-for-the-currents'-plot) and then re-execute the cell for generating the plot. Try!

# %% [markdown]
# Look at the surface current changes from April 2015 to May 2015
#
# The Malvinas Current at 41°S went through two distinct regimes in 2015 referred to as ‘‘weak Malvinas’’ (December 2014 and May–September 2015) and ‘‘strong Malvinas’’ (early January to mid-April 2015 and mid-September to the end of November 2015). The distinct regimes at 41°S can be identified in the in situ and PSY4 velocity components. During the ‘‘strong Malvinas’’ regime the Malvinas Current flows northward 41°S. During the “weak Malvinas” the Malvinas Current retroflects southward and the Brazil Current invades the 41°S section.

# %% [markdown]
# ***

# %% [markdown]
# # 3. Exercise n.2: Plot of transects

# %% [markdown]
# ### Plot transects of temperature, salinity and density

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# In the following we will now look at a transect at 51°S in 2011 observe the strong seasonal changes in that area, in link with the Malvinas current system.

# %% [markdown]
# # 3.1. About the data

# %% [markdown]
# The data are the same used in the [previous exercise](#2.1.-About-the-data).

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# # 3.2. Download the data

# %% [markdown]
# The data can be donwloaded as showed in the [previous exercise](#2.2.-Download-the-data).

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# # 3.3. The exercise

# %% [markdown]
# ### 3.3.1. Set the configuration

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# Set the coordinates min and max values

# %%
depth_min = 0
depth_max = 500 # the MLD is not significant below this level of depth (~192m)
lat_point = -51
lon_min = -65
lon_max = -42

# %% [markdown]
# Set the index for the dataset array

# %%
# selected datasets (comment '#' the unneeded one)
## for year 2011
datasets = file_ds['2011-01'], file_ds['2011-08']

## for year 2015
#datasets = file_ds['2015-04'], file_ds['2015-05']

# %% [markdown]
# Extract the indexes of coordinates

# %%
time_indexes = 0
depth_indexes = getRangeIndexes(datasets[0].depth, depth_min, depth_max)
if ("lat_point" in locals()):
    lon_indexes = getRangeIndexes(lons, lon_min, lon_max)
    lat_indexes = np.abs(lats-lat_point).argmin()
elif ("lon_point" in locals()):
    lon_indexes = np.abs(lons-lon_point).argmin()
    lat_indexes = getRangeIndexes(lats, lat_min, lat_max)

# %% [markdown]
# Extract the coordinates subsets

# %%
lons_sel = datasets[0][lon_name][lon_indexes]
lats_sel = datasets[0][lat_name][lat_indexes]
depths_sel = -datasets[0][depth_name][depth_indexes] # note the minus '-ds'. Why?

# %% [markdown]
# ### 3.3.2. Configure the variables for the plot
# [Go back to the "Table of contents"](#Table-of-contents)

# %%
TEM = [ds[tem_name][time_indexes, depth_indexes, lat_indexes, lon_indexes] for ds in datasets]
SAL = [ds[sal_name][time_indexes, depth_indexes, lat_indexes, lon_indexes] for ds in datasets]
MLD = [ds[mld_name][time_indexes, lat_indexes, lon_indexes] for ds in datasets]
UO = [ds[uo_name][time_indexes, depth_indexes, lat_indexes, lon_indexes] for ds in datasets]

# %% [markdown]
# #### Set the parameters for the plot

# %%
# Plot configuration
width_inch = 14
height_inch = 8

# Axes labels
fontsize = 14
xlabel = "longitude [degN]"
ylabel = "depth [m]"

# Colorbar configuration
cmap = "jet"
cbar_position = "right"

contour_levels = 100

title_fontstyle = {
    "fontsize": "14",
    "fontstyle": "italic",
    "fontweight": "bold",
    "pad": 30
}
label_fontstyle = {
    "fontsize": "12",
#     "labelpad": 10
}

# %% [markdown]
# ### 3.3.3. Function for plotting the transect
# [Go back to the "Table of contents"](#Table-of-contents)

# %%
# arguments:
# - data: data to plot - 2 dim array
# - minmaxvalues: [{ "min": None, "max": None},{ "min": None, "max": None}]
# - step_value: step in levels. If it is 0, then levels = 100
# - title
# - coords_sel
# - depths_sel
def plot_transect(data_plot, minmaxvalues, step_value, title, coords_sel, depths_sel):
    title_sel = title['name']
    title_uni = title['units']
    
    fig = plt.figure(figsize=(width_inch, height_inch))
    
    xx, yy = np.meshgrid(coords_sel, depths_sel)
    
    ### --- PLOT 1 ---###
    fig.add_subplot(1, 2, 1)
    
    idx = 0
    data = data_plot[idx]
  
    # set variable limits
    min_value = data.min() if minmaxvalues[idx]['min'] is None else minmaxvalues[idx]['min']
    max_value = data.max() if minmaxvalues[idx]['max'] is None else minmaxvalues[idx]['max']
    
    #contour_levels = np.arange(min_value, max_value, step_value)  if step_value > 0 else 100

    ## contour fill
    colormesh =  plt.pcolormesh(xx, yy, data, cmap=cmap, vmin=min_value, vmax=max_value)
    
    plt.grid()
    plt.colorbar(colormesh)
    
    # Get the timestep
    timestep = np.datetime_as_string(data.time,'h')
    
    var_str = "{} [{}]".format(title_sel, title_uni)
    title = ' - '.join((var_str, timestep))

    plt.title(title, **title_fontstyle)
    plt.xlabel(xlabel, **label_fontstyle)
    plt.ylabel(ylabel, **label_fontstyle)
    
    
    ### --- PLOT 2 ---###
    fig.add_subplot(1, 2, 2)
    
    idx = 1
    data = data_plot[idx]
    
    # set variable limits
    min_value = data.min() if minmaxvalues[idx]['min'] is None else minmaxvalues[idx]['min']
    max_value = data.max() if minmaxvalues[idx]['max'] is None else minmaxvalues[idx]['max']
    
    #contour_levels = np.arange(min_value, max_value, step_value)  if step_value > 0 else 100
     
    ## contour fill
    colormesh =  plt.pcolormesh(xx, yy, data, cmap=cmap, vmin=min_value, vmax=max_value)
    
    plt.grid()
    plt.colorbar(colormesh)
        
    # Get the timestep
    timestep = np.datetime_as_string(data.time,'h')
    var_str = "{} [{}]".format(title_sel, title_uni)
    title = ' - '.join((var_str, timestep))

    plt.title(title, **title_fontstyle)
    plt.xlabel(xlabel, **label_fontstyle)
    plt.ylabel(ylabel, **label_fontstyle)

    # output file
    output_file = os.path.join(out_path,title.replace(' ','_')) + ".png"

    # save the output file\
    plt.savefig(output_file)

    plt.show()

    plt.close()

# %% [markdown]
# #### Select and plot the dataset for temperature in winter and summer

# %%
data = TEM

title = {"name":"Temperature","units":"degC"}

# plot the transect
plot_transect(data, [{ "min": 1., "max": 8.},{ "min": 1., "max": 8.}], 0, title, lons_sel, depths_sel)

# %% [markdown]
# #### Select and plot the dataset for salinity in winter and summer

# %%
data = SAL

title = {"name":"Salinity","units":"PSU"}

# plot the transect
plot_transect(data, [{ "min": 33, "max": 35},{ "min": None, "max": None}], 0, title, lons_sel, depths_sel)

# %% [markdown]
# Seasonal changes in temperature and salinity are large. In the following, we will also have a look at the zonal current and its vertical structure.

# %% [markdown]
# ### 3.3.4. Density and MLD comparison
# [Go back to the "Table of contents"](#Table-of-contents)

# %%
def plot_density(plot_data, data, MLD, title, coords_sel, depths_sel):
    # def plot_transect2(data, min_value, max_value, step_value):
    fig = plt.figure(figsize=(width_inch, height_inch))

    # Get the timestep
    timestep = np.datetime_as_string(data.time,'h')

    # Create the meshgrid for the plot 
    yy, zz = np.meshgrid(coords_sel, depths_sel)

    ## contour fill
    plt.contourf(yy, zz, plot_data, contour_levels, cmap=cmap)

    plt.grid()
    plt.colorbar(extend='both')

    title_sel = title['name']
    var_str = "{} [{}]".format(title_sel, title['units'])
    title = ' - '.join((var_str, timestep))

    plt.title(title, **title_fontstyle)
    plt.xlabel(xlabel, **label_fontstyle)
    plt.ylabel(ylabel, **label_fontstyle)

    plt.plot(yy[0,:],-MLD, linewidth=2, color='black', label="MLD")
    plt.legend()
    
    # output file
    output_file = os.path.join(out_path, "_".join((title_sel, timestep)) + ".png")

    # save the output file
    plt.savefig(output_file)

    plt.show()

    plt.close()

# %%
j = 0
# Calculate density
rho = density.sigma0(SAL[j],TEM[j])

data = TEM[j]
plot_data = rho

title = {"name":"Density","units":"kg/m^3"}

plot_density(plot_data, data, MLD[j], title, lons_sel, depths_sel)

# %%
j = 1
# Calculate density
rho = density.sigma0(SAL[j],TEM[j])

data = TEM[j]
plot_data = rho

title = {"name":"Density","units":"kg/m^3"}

plot_density(plot_data, data, MLD[j], title, lons_sel, depths_sel)

# %% [markdown]
# Here you have seen the impact of the season and of the ocean circulation changes on the physical properties of the marine water at different latitudes, and the corresponding change in the mixed layer depth too.

# %% [markdown]
# The Mixed Layer Depth changes from 10 m in January (strong summer thermocline) to over 500 m in August region due to important winter convection.
#
# In winter the western portion of the section shows larger mixed layer depths than the eastern portion.
# Waters in the west correspond to Subantarctic waters, less dense than Polar waters located in the eastern portion.
#
# NB: in this notebook monthly means are used while daily outputs were used in the reference article, have a look at the reference articles for further illustrations and validation of the GLO MFC products in the area with different sources of observations, including independant (not assimilated) in situ observations.

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# ***

# %% [markdown]
# # 4. Conclusion

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>CONGRATULATIONS</b><br>
#
# ---
#
# #### Now you know how to plot the Global physical model provided by Copernicus Marine Service, for free, thanks to the European Commission.
#
# #### To go further, you can try to visualize other variables and diagnostics (spatial or vertical averages, standard deviations...)
#
# #### Hope you have enjoyed this session and let's do great science with our data.
#
# This training course is over but we'd love to hear from you about how we could improve it (topics, tools, storytelling, format, speed etc).

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)
